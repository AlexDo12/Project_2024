# %%
import sys
from glob import glob
import matplotlib.pyplot as plt
import pandas as pd
import thicket as th
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
# Out:
# Warning: Roundtrip module could not be loaded. Requires jupyter notebook version <= 7.x.

# %%
tk = th.Thicket.from_caliperreader(glob("RandomWeakScaling/*.cali"))
# Out:
# (1/2) Reading Files: 100%|██████████| 5/5 [00:00<00:00, 11.07it/s]
# (2/2) Creating Thicket: 100%|██████████| 4/4 [00:00<00:00, 496.78it/s]
# /home/ado/.local/lib/python3.10/site-packages/thicket/ensemble.py:409: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].replace({numerical_fill_value: None}, inplace=True)

# %%
tk.metadata
# Out:
#            cali.caliper.version  mpi.world.size  \
# profile
# 34514284                 2.11.0             128
# 51158898                 2.11.0              16
# 210478988                2.11.0               2
# 389822904                2.11.0               8
# 1161105437               2.11.0               4
# 1656300721               2.11.0             256
# 1876752849               2.11.0               8
# 2019302383               2.11.0              64
# 2405902553               2.11.0             512
# 2466704898               2.11.0               2
# 2570818907               2.11.0             128
# 2680675339               2.11.0               4
# 2939914029               2.11.0              64
# 2957797805               2.11.0             256
# 3113931281               2.11.0            1024
# 3265756731               2.11.0              16
# 3472188329               2.11.0             512
# 3947188472               2.11.0              32
# 3950392994               2.11.0              32
#
#                                                  spot.metrics  \
# profile
# 34514284    min#inclusive#sum#time.duration,max#inclusive#...
# 51158898    min#inclusive#sum#time.duration,max#inclusive#...
# 210478988   min#inclusive#sum#time.duration,max#inclusive#...
# 389822904   min#inclusive#sum#time.duration,max#inclusive#...
# 1161105437  min#inclusive#sum#time.duration,max#inclusive#...
# 1656300721  min#inclusive#sum#time.duration,max#inclusive#...
# 1876752849  min#inclusive#sum#time.duration,max#inclusive#...
# 2019302383  min#inclusive#sum#time.duration,max#inclusive#...
# 2405902553  min#inclusive#sum#time.duration,max#inclusive#...
# 2466704898  min#inclusive#sum#time.duration,max#inclusive#...
# 2570818907  min#inclusive#sum#time.duration,max#inclusive#...
# 2680675339  min#inclusive#sum#time.duration,max#inclusive#...
# 2939914029  min#inclusive#sum#time.duration,max#inclusive#...
# 2957797805  min#inclusive#sum#time.duration,max#inclusive#...
# 3113931281  min#inclusive#sum#time.duration,max#inclusive#...
# 3265756731  min#inclusive#sum#time.duration,max#inclusive#...
# 3472188329  min#inclusive#sum#time.duration,max#inclusive#...
# 3947188472  min#inclusive#sum#time.duration,max#inclusive#...
# 3950392994  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 34514284                                              2
# 51158898                                              2
# 210478988                                             2
# 389822904                                             2
# 1161105437                                            2
# 1656300721                                            2
# 1876752849                                            2
# 2019302383                                            2
# 2405902553                                            2
# 2466704898                                            2
# 2570818907                                            2
# 2680675339                                            2
# 2939914029                                            2
# 2957797805                                            2
# 3113931281                                            2
# 3265756731                                            2
# 3472188329                                            2
# 3947188472                                            2
# 3950392994                                            2
#
#                                                  spot.options  spot.channels  \
# profile
# 34514284    time.variance,profile.mpi,node.order,region.co...  regionprofile
# 51158898    time.variance,profile.mpi,node.order,region.co...  regionprofile
# 210478988   time.variance,profile.mpi,node.order,region.co...  regionprofile
# 389822904   time.variance,profile.mpi,node.order,region.co...  regionprofile
# 1161105437  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 1656300721  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 1876752849  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 2019302383  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 2405902553  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 2466704898  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 2570818907  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 2680675339  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 2939914029  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 2957797805  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 3113931281  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 3265756731  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 3472188329  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 3947188472  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 3950392994  time.variance,profile.mpi,node.order,region.co...  regionprofile
#
#            cali.channel spot:node.order  \
# profile
# 34514284           spot            true
# 51158898           spot            true
# 210478988          spot            true
# 389822904          spot            true
# 1161105437         spot            true
# 1656300721         spot            true
# 1876752849         spot            true
# 2019302383         spot            true
# 2405902553         spot            true
# 2466704898         spot            true
# 2570818907         spot            true
# 2680675339         spot            true
# 2939914029         spot            true
# 2957797805         spot            true
# 3113931281         spot            true
# 3265756731         spot            true
# 3472188329         spot            true
# 3947188472         spot            true
# 3950392994         spot            true
#
#                                         spot:output spot:profile.mpi  \
# profile
# 34514284                         p128-a4194304.cali             true
# 51158898                          p16-a4194304.cali             true
# 210478988                          p2-a4194304.cali             true
# 389822904     p8-a4194304-sbitonic-i1perturbed.cali             true
# 1161105437    p4-a4194304-sbitonic-i1perturbed.cali             true
# 1656300721                       p256-a4194304.cali             true
# 1876752849                         p8-a4194304.cali             true
# 2019302383   p64-a4194304-sbitonic-i1perturbed.cali             true
# 2405902553                       p512-a4194304.cali             true
# 2466704898    p2-a4194304-sbitonic-i1perturbed.cali             true
# 2570818907  p128-a4194304-sbitonic-i1perturbed.cali             true
# 2680675339                         p4-a4194304.cali             true
# 2939914029                        p64-a4194304.cali             true
# 2957797805  p256-a4194304-sbitonic-i1perturbed.cali             true
# 3113931281                      p1024-a4194304.cali             true
# 3265756731   p16-a4194304-sbitonic-i1perturbed.cali             true
# 3472188329  p512-a4194304-sbitonic-i1perturbed.cali             true
# 3947188472   p32-a4194304-sbitonic-i1perturbed.cali             true
# 3950392994                        p32-a4194304.cali             true
#
#            spot:region.count spot:time.exclusive spot:time.variance  \
# profile
# 34514284                true                true               true
# 51158898                true                true               true
# 210478988               true                true               true
# 389822904               true                true               true
# 1161105437              true                true               true
# 1656300721              true                true               true
# 1876752849              true                true               true
# 2019302383              true                true               true
# 2405902553              true                true               true
# 2466704898              true                true               true
# 2570818907              true                true               true
# 2680675339              true                true               true
# 2939914029              true                true               true
# 2957797805              true                true               true
# 3113931281              true                true               true
# 3265756731              true                true               true
# 3472188329              true                true               true
# 3947188472              true                true               true
# 3950392994              true                true               true
#
#             launchdate                                          libraries  \
# profile
# 34514284    1729438431  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 51158898    1729438431  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 210478988   1729438431  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 389822904   1729560208  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 1161105437  1729560209  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 1656300721  1729438447  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 1876752849  1729438430  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 2019302383  1729561066  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 2405902553  1729438447  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 2466704898  1729560206  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 2570818907  1729561065  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 2680675339  1729438432  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 2939914029  1729438431  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 2957797805  1729561041  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 3113931281  1729439180  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 3265756731  1729560206  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 3472188329  1729561039  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 3947188472  1729561063  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 3950392994  1729438431  [/scratch/group/csce435-f24/Caliper/caliper/li...
#
#                                            cmdline cluster algorithm  \
# profile
# 34514284        [./main, 4194304, bitonic, random]       c   bitonic
# 51158898        [./main, 4194304, bitonic, random]       c   bitonic
# 210478988       [./main, 4194304, bitonic, random]       c   bitonic
# 389822904   [./main, 4194304, bitonic, 1perturbed]       c   bitonic
# 1161105437  [./main, 4194304, bitonic, 1perturbed]       c   bitonic
# 1656300721      [./main, 4194304, bitonic, random]       c   bitonic
# 1876752849      [./main, 4194304, bitonic, random]       c   bitonic
# 2019302383  [./main, 4194304, bitonic, 1perturbed]       c   bitonic
# 2405902553      [./main, 4194304, bitonic, random]       c   bitonic
# 2466704898  [./main, 4194304, bitonic, 1perturbed]       c   bitonic
# 2570818907  [./main, 4194304, bitonic, 1perturbed]       c   bitonic
# 2680675339      [./main, 4194304, bitonic, random]       c   bitonic
# 2939914029      [./main, 4194304, bitonic, random]       c   bitonic
# 2957797805  [./main, 4194304, bitonic, 1perturbed]       c   bitonic
# 3113931281      [./main, 4194304, bitonic, random]       c   bitonic
# 3265756731  [./main, 4194304, bitonic, 1perturbed]       c   bitonic
# 3472188329  [./main, 4194304, bitonic, 1perturbed]       c   bitonic
# 3947188472  [./main, 4194304, bitonic, 1perturbed]       c   bitonic
# 3950392994      [./main, 4194304, bitonic, random]       c   bitonic
#
#            programming_model data_type  size_of_data_type  input_size  \
# profile
# 34514284                 mpi       int                  4     4194304
# 51158898                 mpi       int                  4     4194304
# 210478988                mpi       int                  4     4194304
# 389822904                mpi       int                  4     4194304
# 1161105437               mpi       int                  4     4194304
# 1656300721               mpi       int                  4     4194304
# 1876752849               mpi       int                  4     4194304
# 2019302383               mpi       int                  4     4194304
# 2405902553               mpi       int                  4     4194304
# 2466704898               mpi       int                  4     4194304
# 2570818907               mpi       int                  4     4194304
# 2680675339               mpi       int                  4     4194304
# 2939914029               mpi       int                  4     4194304
# 2957797805               mpi       int                  4     4194304
# 3113931281               mpi       int                  4     4194304
# 3265756731               mpi       int                  4     4194304
# 3472188329               mpi       int                  4     4194304
# 3947188472               mpi       int                  4     4194304
# 3950392994               mpi       int                  4     4194304
#
#             input_type  num_procs  group_num implementation_source scalability
# profile
# 34514284        random        128          8                online        weak
# 51158898        random         16          8                online        weak
# 210478988       random          2          8                online        weak
# 389822904   1perturbed          8          8                online        weak
# 1161105437  1perturbed          4          8                online        weak
# 1656300721      random        256          8                online        weak
# 1876752849      random          8          8                online        weak
# 2019302383  1perturbed         64          8                online        weak
# 2405902553      random        512          8                online        weak
# 2466704898  1perturbed          2          8                online        weak
# 2570818907  1perturbed        128          8                online        weak
# 2680675339      random          4          8                online        weak
# 2939914029      random         64          8                online        weak
# 2957797805  1perturbed        256          8                online        weak
# 3113931281      random       1024          8                online        weak
# 3265756731  1perturbed         16          8                online        weak
# 3472188329  1perturbed        512          8                online        weak
# 3947188472  1perturbed         32          8                online        weak
# 3950392994      random         32          8                online        weak

# %%
print(tk.tree(metric_column="Avg time/rank"))
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2024.1.0
#
# 0.319 main
# ├─ 0.001 MPI_Comm_dup
# ├─ 0.003 MPI_Comm_split
# ├─ 0.000 MPI_Finalize
# ├─ 0.000 MPI_Finalized
# ├─ 0.000 MPI_Init
# ├─ 0.000 MPI_Initialized
# ├─ 0.002 comm
# │  ├─ 0.002 comm_large
# │  │  ├─ 0.000 MPI_Gather
# │  │  ├─ 0.001 MPI_Scatter
# │  │  └─ 0.001 MPI_Sendrecv
# │  └─ 0.000 comm_small
# │     ├─ 0.000 MPI_Barrier
# │     └─ 0.000 MPI_Bcast
# ├─ 0.013 comp
# │  └─ 0.013 comp_large
# ├─ 0.001 correctness_check
# └─ 0.001 data_init_runtime
#    └─ 0.000 MPI_Gather
#
# Legend (Metric: Avg time/rank Min: 0.00 Max: 0.32 indices: {'profile': np.int64(1494377952)})
# █ 0.29 - 0.32
# █ 0.22 - 0.29
# █ 0.16 - 0.22
# █ 0.10 - 0.16
# █ 0.03 - 0.10
# █ 0.00 - 0.03
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
tk.metadata_column_to_perfdata("num_procs")
tk.metadata_column_to_perfdata("input_type")
tk.metadata_column_to_perfdata("input_size")
tk.dataframe = tk.dataframe.reset_index()
tk.dataframe.head()
# Out:
#                                    node     profile  nid   spot.channel  \
# 0  {'name': 'main', 'type': 'function'}  1494377952  1.0  regionprofile
# 1  {'name': 'main', 'type': 'function'}  1989587635  1.0  regionprofile
# 2  {'name': 'main', 'type': 'function'}  2316993084  1.0  regionprofile
# 3  {'name': 'main', 'type': 'function'}  2832766688  1.0  regionprofile
# 4  {'name': 'main', 'type': 'function'}  3515466618  1.0  regionprofile
#
#    Min time/rank  Max time/rank  Avg time/rank   Total time  \
# 0       0.318754       0.318771       0.318763     0.637525
# 1       2.573379       2.617058       2.592586  1327.404064
# 2       1.763461       1.842706       1.832548   469.132250
# 3       0.660049       0.662389       0.661132     5.289057
# 4       2.162364       2.185724       2.174416   278.325248
#
#    Variance time/rank  Min time/rank (exc)  Max time/rank (exc)  \
# 0            0.000000             0.294356             0.299166
# 1            0.000106             1.766852             1.954715
# 2            0.000050             1.657065             1.756763
# 3            0.000001             0.605018             0.611685
# 4            0.000101             1.890610             1.925751
#
#    Avg time/rank (exc)  Total time (exc)  Calls/rank (min)  Calls/rank (avg)  \
# 0             0.296761          0.593522               NaN               NaN
# 1             1.855106        949.814337               NaN               NaN
# 2             1.715178        439.085484               NaN               NaN
# 3             0.607433          4.859464               NaN               NaN
# 4             1.911400        244.659139               NaN               NaN
#
#    Calls/rank (max)  Calls/rank (total)  name  num_procs input_type  \
# 0               NaN                 NaN  main          2     random
# 1               NaN                 NaN  main        512     random
# 2               NaN                 NaN  main        256     random
# 3               NaN                 NaN  main          8     random
# 4               NaN                 NaN  main        128     random
#
#    input_size
# 0       65536
# 1    16777216
# 2     1048576
# 3      262144
# 4     4194304

# %%
def plot_pandas(df, title, xlabel, ylabel):
    plot = df.plot(kind="line",
    marker='o',
    title=title,
    xlabel=xlabel,
    ylabel=ylabel,
    figsize=(15,7)
    )
    return plot

# %%
input_sizes = [65536, 262144, 1048576, 4194304, 16777216]
input_types = ["random", "sorted", "reverse", "1perturbed"]

# Function to create weak scaling plots
def plot_weak_scaling(tk, input_types):
    for node in tk.graph.traverse():
        node_name = node.frame['name']
        if (node_name == 'comp_large') or (node_name == 'comm') or (node_name == 'main'):
            for input_type in input_types:
                fig, ax = plt.subplots(figsize=(10, 6))
                for input_size in input_sizes:
                    data = tk.dataframe[(tk.dataframe["input_type"] == input_type) & (tk.dataframe["input_size"] == input_size) & (tk.dataframe['node'] == node)]
                    ax.plot(data["num_procs"], data["Avg time/rank"], marker='o', label=f'Input Size {input_size}')
                ax.set_title(f'Weak Scaling for {input_type} on {node_name}')
                ax.set_xlabel('Number of Processors')
                ax.set_ylabel('Average Time per Rank (seconds)')
                ax.legend()
                plt.show()


plot_weak_scaling(tk, input_types)

# %%
tk.dataframe = tk.dataframe.reset_index()#.set_index(["node"])
tk.dataframe
# Out:
#                                                   node  num_procs     profile  \
# 0                 {'name': 'main', 'type': 'function'}        128    34514284
# 1                 {'name': 'main', 'type': 'function'}         16    51158898
# 2                 {'name': 'main', 'type': 'function'}          2   210478988
# 3                 {'name': 'main', 'type': 'function'}          8   389822904
# 4                 {'name': 'main', 'type': 'function'}          4  1161105437
# 5                 {'name': 'main', 'type': 'function'}        256  1656300721
# 6                 {'name': 'main', 'type': 'function'}          8  1876752849
# 7                 {'name': 'main', 'type': 'function'}         64  2019302383
# 8                 {'name': 'main', 'type': 'function'}        512  2405902553
# 9                 {'name': 'main', 'type': 'function'}          2  2466704898
# 10                {'name': 'main', 'type': 'function'}        128  2570818907
# 11                {'name': 'main', 'type': 'function'}          4  2680675339
# 12                {'name': 'main', 'type': 'function'}         64  2939914029
# 13                {'name': 'main', 'type': 'function'}        256  2957797805
# 14                {'name': 'main', 'type': 'function'}       1024  3113931281
# 15                {'name': 'main', 'type': 'function'}         16  3265756731
# 16                {'name': 'main', 'type': 'function'}        512  3472188329
# 17                {'name': 'main', 'type': 'function'}         32  3947188472
# 18                {'name': 'main', 'type': 'function'}         32  3950392994
# 19        {'name': 'MPI_Comm_dup', 'type': 'function'}        128    34514284
# 20        {'name': 'MPI_Comm_dup', 'type': 'function'}         16    51158898
# 21        {'name': 'MPI_Comm_dup', 'type': 'function'}          2   210478988
# 22        {'name': 'MPI_Comm_dup', 'type': 'function'}          8   389822904
# 23        {'name': 'MPI_Comm_dup', 'type': 'function'}          4  1161105437
# 24        {'name': 'MPI_Comm_dup', 'type': 'function'}        256  1656300721
# 25        {'name': 'MPI_Comm_dup', 'type': 'function'}          8  1876752849
# 26        {'name': 'MPI_Comm_dup', 'type': 'function'}         64  2019302383
# 27        {'name': 'MPI_Comm_dup', 'type': 'function'}        512  2405902553
# 28        {'name': 'MPI_Comm_dup', 'type': 'function'}          2  2466704898
# 29        {'name': 'MPI_Comm_dup', 'type': 'function'}        128  2570818907
# 30        {'name': 'MPI_Comm_dup', 'type': 'function'}          4  2680675339
# 31        {'name': 'MPI_Comm_dup', 'type': 'function'}         64  2939914029
# 32        {'name': 'MPI_Comm_dup', 'type': 'function'}        256  2957797805
# 33        {'name': 'MPI_Comm_dup', 'type': 'function'}       1024  3113931281
# 34        {'name': 'MPI_Comm_dup', 'type': 'function'}         16  3265756731
# 35        {'name': 'MPI_Comm_dup', 'type': 'function'}        512  3472188329
# 36        {'name': 'MPI_Comm_dup', 'type': 'function'}         32  3947188472
# 37        {'name': 'MPI_Comm_dup', 'type': 'function'}         32  3950392994
# 38      {'name': 'MPI_Comm_split', 'type': 'function'}        128    34514284
# 39      {'name': 'MPI_Comm_split', 'type': 'function'}         16    51158898
# 40      {'name': 'MPI_Comm_split', 'type': 'function'}          2   210478988
# 41      {'name': 'MPI_Comm_split', 'type': 'function'}          8   389822904
# 42      {'name': 'MPI_Comm_split', 'type': 'function'}          4  1161105437
# 43      {'name': 'MPI_Comm_split', 'type': 'function'}        256  1656300721
# 44      {'name': 'MPI_Comm_split', 'type': 'function'}          8  1876752849
# 45      {'name': 'MPI_Comm_split', 'type': 'function'}         64  2019302383
# 46      {'name': 'MPI_Comm_split', 'type': 'function'}        512  2405902553
# 47      {'name': 'MPI_Comm_split', 'type': 'function'}          2  2466704898
# 48      {'name': 'MPI_Comm_split', 'type': 'function'}        128  2570818907
# 49      {'name': 'MPI_Comm_split', 'type': 'function'}          4  2680675339
# 50      {'name': 'MPI_Comm_split', 'type': 'function'}         64  2939914029
# 51      {'name': 'MPI_Comm_split', 'type': 'function'}        256  2957797805
# 52      {'name': 'MPI_Comm_split', 'type': 'function'}       1024  3113931281
# 53      {'name': 'MPI_Comm_split', 'type': 'function'}         16  3265756731
# 54      {'name': 'MPI_Comm_split', 'type': 'function'}        512  3472188329
# 55      {'name': 'MPI_Comm_split', 'type': 'function'}         32  3947188472
# 56      {'name': 'MPI_Comm_split', 'type': 'function'}         32  3950392994
# 57        {'name': 'MPI_Finalize', 'type': 'function'}        128    34514284
# 58        {'name': 'MPI_Finalize', 'type': 'function'}         16    51158898
# 59        {'name': 'MPI_Finalize', 'type': 'function'}          2   210478988
# 60        {'name': 'MPI_Finalize', 'type': 'function'}          8   389822904
# 61        {'name': 'MPI_Finalize', 'type': 'function'}          4  1161105437
# 62        {'name': 'MPI_Finalize', 'type': 'function'}        256  1656300721
# 63        {'name': 'MPI_Finalize', 'type': 'function'}          8  1876752849
# 64        {'name': 'MPI_Finalize', 'type': 'function'}         64  2019302383
# 65        {'name': 'MPI_Finalize', 'type': 'function'}        512  2405902553
# 66        {'name': 'MPI_Finalize', 'type': 'function'}          2  2466704898
# 67        {'name': 'MPI_Finalize', 'type': 'function'}        128  2570818907
# 68        {'name': 'MPI_Finalize', 'type': 'function'}          4  2680675339
# 69        {'name': 'MPI_Finalize', 'type': 'function'}         64  2939914029
# 70        {'name': 'MPI_Finalize', 'type': 'function'}        256  2957797805
# 71        {'name': 'MPI_Finalize', 'type': 'function'}       1024  3113931281
# 72        {'name': 'MPI_Finalize', 'type': 'function'}         16  3265756731
# 73        {'name': 'MPI_Finalize', 'type': 'function'}        512  3472188329
# 74        {'name': 'MPI_Finalize', 'type': 'function'}         32  3947188472
# 75        {'name': 'MPI_Finalize', 'type': 'function'}         32  3950392994
# 76       {'name': 'MPI_Finalized', 'type': 'function'}        128    34514284
# 77       {'name': 'MPI_Finalized', 'type': 'function'}         16    51158898
# 78       {'name': 'MPI_Finalized', 'type': 'function'}          2   210478988
# 79       {'name': 'MPI_Finalized', 'type': 'function'}          8   389822904
# 80       {'name': 'MPI_Finalized', 'type': 'function'}          4  1161105437
# 81       {'name': 'MPI_Finalized', 'type': 'function'}        256  1656300721
# 82       {'name': 'MPI_Finalized', 'type': 'function'}          8  1876752849
# 83       {'name': 'MPI_Finalized', 'type': 'function'}         64  2019302383
# 84       {'name': 'MPI_Finalized', 'type': 'function'}        512  2405902553
# 85       {'name': 'MPI_Finalized', 'type': 'function'}          2  2466704898
# 86       {'name': 'MPI_Finalized', 'type': 'function'}        128  2570818907
# 87       {'name': 'MPI_Finalized', 'type': 'function'}          4  2680675339
# 88       {'name': 'MPI_Finalized', 'type': 'function'}         64  2939914029
# 89       {'name': 'MPI_Finalized', 'type': 'function'}        256  2957797805
# 90       {'name': 'MPI_Finalized', 'type': 'function'}       1024  3113931281
# 91       {'name': 'MPI_Finalized', 'type': 'function'}         16  3265756731
# 92       {'name': 'MPI_Finalized', 'type': 'function'}        512  3472188329
# 93       {'name': 'MPI_Finalized', 'type': 'function'}         32  3947188472
# 94       {'name': 'MPI_Finalized', 'type': 'function'}         32  3950392994
# 95            {'name': 'MPI_Init', 'type': 'function'}        128    34514284
# 96            {'name': 'MPI_Init', 'type': 'function'}         16    51158898
# 97            {'name': 'MPI_Init', 'type': 'function'}          2   210478988
# 98            {'name': 'MPI_Init', 'type': 'function'}          8   389822904
# 99            {'name': 'MPI_Init', 'type': 'function'}          4  1161105437
# 100           {'name': 'MPI_Init', 'type': 'function'}        256  1656300721
# 101           {'name': 'MPI_Init', 'type': 'function'}          8  1876752849
# 102           {'name': 'MPI_Init', 'type': 'function'}         64  2019302383
# 103           {'name': 'MPI_Init', 'type': 'function'}        512  2405902553
# 104           {'name': 'MPI_Init', 'type': 'function'}          2  2466704898
# 105           {'name': 'MPI_Init', 'type': 'function'}        128  2570818907
# 106           {'name': 'MPI_Init', 'type': 'function'}          4  2680675339
# 107           {'name': 'MPI_Init', 'type': 'function'}         64  2939914029
# 108           {'name': 'MPI_Init', 'type': 'function'}        256  2957797805
# 109           {'name': 'MPI_Init', 'type': 'function'}       1024  3113931281
# 110           {'name': 'MPI_Init', 'type': 'function'}         16  3265756731
# 111           {'name': 'MPI_Init', 'type': 'function'}        512  3472188329
# 112           {'name': 'MPI_Init', 'type': 'function'}         32  3947188472
# 113           {'name': 'MPI_Init', 'type': 'function'}         32  3950392994
# 114    {'name': 'MPI_Initialized', 'type': 'function'}        128    34514284
# 115    {'name': 'MPI_Initialized', 'type': 'function'}         16    51158898
# 116    {'name': 'MPI_Initialized', 'type': 'function'}          2   210478988
# 117    {'name': 'MPI_Initialized', 'type': 'function'}          8   389822904
# 118    {'name': 'MPI_Initialized', 'type': 'function'}          4  1161105437
# 119    {'name': 'MPI_Initialized', 'type': 'function'}        256  1656300721
# 120    {'name': 'MPI_Initialized', 'type': 'function'}          8  1876752849
# 121    {'name': 'MPI_Initialized', 'type': 'function'}         64  2019302383
# 122    {'name': 'MPI_Initialized', 'type': 'function'}        512  2405902553
# 123    {'name': 'MPI_Initialized', 'type': 'function'}          2  2466704898
# 124    {'name': 'MPI_Initialized', 'type': 'function'}        128  2570818907
# 125    {'name': 'MPI_Initialized', 'type': 'function'}          4  2680675339
# 126    {'name': 'MPI_Initialized', 'type': 'function'}         64  2939914029
# 127    {'name': 'MPI_Initialized', 'type': 'function'}        256  2957797805
# 128    {'name': 'MPI_Initialized', 'type': 'function'}       1024  3113931281
# 129    {'name': 'MPI_Initialized', 'type': 'function'}         16  3265756731
# 130    {'name': 'MPI_Initialized', 'type': 'function'}        512  3472188329
# 131    {'name': 'MPI_Initialized', 'type': 'function'}         32  3947188472
# 132    {'name': 'MPI_Initialized', 'type': 'function'}         32  3950392994
# 133               {'name': 'comm', 'type': 'function'}        128    34514284
# 134               {'name': 'comm', 'type': 'function'}         16    51158898
# 135               {'name': 'comm', 'type': 'function'}          2   210478988
# 136               {'name': 'comm', 'type': 'function'}          8   389822904
# 137               {'name': 'comm', 'type': 'function'}          4  1161105437
# 138               {'name': 'comm', 'type': 'function'}        256  1656300721
# 139               {'name': 'comm', 'type': 'function'}          8  1876752849
# 140               {'name': 'comm', 'type': 'function'}         64  2019302383
# 141               {'name': 'comm', 'type': 'function'}        512  2405902553
# 142               {'name': 'comm', 'type': 'function'}          2  2466704898
# 143               {'name': 'comm', 'type': 'function'}        128  2570818907
# 144               {'name': 'comm', 'type': 'function'}          4  2680675339
# 145               {'name': 'comm', 'type': 'function'}         64  2939914029
# 146               {'name': 'comm', 'type': 'function'}        256  2957797805
# 147               {'name': 'comm', 'type': 'function'}       1024  3113931281
# 148               {'name': 'comm', 'type': 'function'}         16  3265756731
# 149               {'name': 'comm', 'type': 'function'}        512  3472188329
# 150               {'name': 'comm', 'type': 'function'}         32  3947188472
# 151               {'name': 'comm', 'type': 'function'}         32  3950392994
# 152         {'name': 'comm_large', 'type': 'function'}        128    34514284
# 153         {'name': 'comm_large', 'type': 'function'}         16    51158898
# 154         {'name': 'comm_large', 'type': 'function'}          2   210478988
# 155         {'name': 'comm_large', 'type': 'function'}          8   389822904
# 156         {'name': 'comm_large', 'type': 'function'}          4  1161105437
# 157         {'name': 'comm_large', 'type': 'function'}        256  1656300721
# 158         {'name': 'comm_large', 'type': 'function'}          8  1876752849
# 159         {'name': 'comm_large', 'type': 'function'}         64  2019302383
# 160         {'name': 'comm_large', 'type': 'function'}        512  2405902553
# 161         {'name': 'comm_large', 'type': 'function'}          2  2466704898
# 162         {'name': 'comm_large', 'type': 'function'}        128  2570818907
# 163         {'name': 'comm_large', 'type': 'function'}          4  2680675339
# 164         {'name': 'comm_large', 'type': 'function'}         64  2939914029
# 165         {'name': 'comm_large', 'type': 'function'}        256  2957797805
# 166         {'name': 'comm_large', 'type': 'function'}       1024  3113931281
# 167         {'name': 'comm_large', 'type': 'function'}         16  3265756731
# 168         {'name': 'comm_large', 'type': 'function'}        512  3472188329
# 169         {'name': 'comm_large', 'type': 'function'}         32  3947188472
# 170         {'name': 'comm_large', 'type': 'function'}         32  3950392994
# 171         {'name': 'MPI_Gather', 'type': 'function'}        128    34514284
# 172         {'name': 'MPI_Gather', 'type': 'function'}         16    51158898
# 173         {'name': 'MPI_Gather', 'type': 'function'}          2   210478988
# 174         {'name': 'MPI_Gather', 'type': 'function'}          8   389822904
# 175         {'name': 'MPI_Gather', 'type': 'function'}          4  1161105437
# 176         {'name': 'MPI_Gather', 'type': 'function'}        256  1656300721
# 177         {'name': 'MPI_Gather', 'type': 'function'}          8  1876752849
# 178         {'name': 'MPI_Gather', 'type': 'function'}         64  2019302383
# 179         {'name': 'MPI_Gather', 'type': 'function'}        512  2405902553
# 180         {'name': 'MPI_Gather', 'type': 'function'}          2  2466704898
# 181         {'name': 'MPI_Gather', 'type': 'function'}        128  2570818907
# 182         {'name': 'MPI_Gather', 'type': 'function'}          4  2680675339
# 183         {'name': 'MPI_Gather', 'type': 'function'}         64  2939914029
# 184         {'name': 'MPI_Gather', 'type': 'function'}        256  2957797805
# 185         {'name': 'MPI_Gather', 'type': 'function'}       1024  3113931281
# 186         {'name': 'MPI_Gather', 'type': 'function'}         16  3265756731
# 187         {'name': 'MPI_Gather', 'type': 'function'}        512  3472188329
# 188         {'name': 'MPI_Gather', 'type': 'function'}         32  3947188472
# 189         {'name': 'MPI_Gather', 'type': 'function'}         32  3950392994
# 190        {'name': 'MPI_Scatter', 'type': 'function'}        128    34514284
# 191        {'name': 'MPI_Scatter', 'type': 'function'}         16    51158898
# 192        {'name': 'MPI_Scatter', 'type': 'function'}          2   210478988
# 193        {'name': 'MPI_Scatter', 'type': 'function'}          8   389822904
# 194        {'name': 'MPI_Scatter', 'type': 'function'}          4  1161105437
# 195        {'name': 'MPI_Scatter', 'type': 'function'}        256  1656300721
# 196        {'name': 'MPI_Scatter', 'type': 'function'}          8  1876752849
# 197        {'name': 'MPI_Scatter', 'type': 'function'}         64  2019302383
# 198        {'name': 'MPI_Scatter', 'type': 'function'}        512  2405902553
# 199        {'name': 'MPI_Scatter', 'type': 'function'}          2  2466704898
# 200        {'name': 'MPI_Scatter', 'type': 'function'}        128  2570818907
# 201        {'name': 'MPI_Scatter', 'type': 'function'}          4  2680675339
# 202        {'name': 'MPI_Scatter', 'type': 'function'}         64  2939914029
# 203        {'name': 'MPI_Scatter', 'type': 'function'}        256  2957797805
# 204        {'name': 'MPI_Scatter', 'type': 'function'}       1024  3113931281
# 205        {'name': 'MPI_Scatter', 'type': 'function'}         16  3265756731
# 206        {'name': 'MPI_Scatter', 'type': 'function'}        512  3472188329
# 207        {'name': 'MPI_Scatter', 'type': 'function'}         32  3947188472
# 208        {'name': 'MPI_Scatter', 'type': 'function'}         32  3950392994
# 209       {'name': 'MPI_Sendrecv', 'type': 'function'}        128    34514284
# 210       {'name': 'MPI_Sendrecv', 'type': 'function'}         16    51158898
# 211       {'name': 'MPI_Sendrecv', 'type': 'function'}          2   210478988
# 212       {'name': 'MPI_Sendrecv', 'type': 'function'}          8   389822904
# 213       {'name': 'MPI_Sendrecv', 'type': 'function'}          4  1161105437
# 214       {'name': 'MPI_Sendrecv', 'type': 'function'}        256  1656300721
# 215       {'name': 'MPI_Sendrecv', 'type': 'function'}          8  1876752849
# 216       {'name': 'MPI_Sendrecv', 'type': 'function'}         64  2019302383
# 217       {'name': 'MPI_Sendrecv', 'type': 'function'}        512  2405902553
# 218       {'name': 'MPI_Sendrecv', 'type': 'function'}          2  2466704898
# 219       {'name': 'MPI_Sendrecv', 'type': 'function'}        128  2570818907
# 220       {'name': 'MPI_Sendrecv', 'type': 'function'}          4  2680675339
# 221       {'name': 'MPI_Sendrecv', 'type': 'function'}         64  2939914029
# 222       {'name': 'MPI_Sendrecv', 'type': 'function'}        256  2957797805
# 223       {'name': 'MPI_Sendrecv', 'type': 'function'}       1024  3113931281
# 224       {'name': 'MPI_Sendrecv', 'type': 'function'}         16  3265756731
# 225       {'name': 'MPI_Sendrecv', 'type': 'function'}        512  3472188329
# 226       {'name': 'MPI_Sendrecv', 'type': 'function'}         32  3947188472
# 227       {'name': 'MPI_Sendrecv', 'type': 'function'}         32  3950392994
# 228         {'name': 'comm_small', 'type': 'function'}        128    34514284
# 229         {'name': 'comm_small', 'type': 'function'}         16    51158898
# 230         {'name': 'comm_small', 'type': 'function'}          2   210478988
# 231         {'name': 'comm_small', 'type': 'function'}          8   389822904
# 232         {'name': 'comm_small', 'type': 'function'}          4  1161105437
# 233         {'name': 'comm_small', 'type': 'function'}        256  1656300721
# 234         {'name': 'comm_small', 'type': 'function'}          8  1876752849
# 235         {'name': 'comm_small', 'type': 'function'}         64  2019302383
# 236         {'name': 'comm_small', 'type': 'function'}        512  2405902553
# 237         {'name': 'comm_small', 'type': 'function'}          2  2466704898
# 238         {'name': 'comm_small', 'type': 'function'}        128  2570818907
# 239         {'name': 'comm_small', 'type': 'function'}          4  2680675339
# 240         {'name': 'comm_small', 'type': 'function'}         64  2939914029
# 241         {'name': 'comm_small', 'type': 'function'}        256  2957797805
# 242         {'name': 'comm_small', 'type': 'function'}       1024  3113931281
# 243         {'name': 'comm_small', 'type': 'function'}         16  3265756731
# 244         {'name': 'comm_small', 'type': 'function'}        512  3472188329
# 245         {'name': 'comm_small', 'type': 'function'}         32  3947188472
# 246         {'name': 'comm_small', 'type': 'function'}         32  3950392994
# 247        {'name': 'MPI_Barrier', 'type': 'function'}        128    34514284
# 248        {'name': 'MPI_Barrier', 'type': 'function'}         16    51158898
# 249        {'name': 'MPI_Barrier', 'type': 'function'}          2   210478988
# 250        {'name': 'MPI_Barrier', 'type': 'function'}          8   389822904
# 251        {'name': 'MPI_Barrier', 'type': 'function'}          4  1161105437
# 252        {'name': 'MPI_Barrier', 'type': 'function'}        256  1656300721
# 253        {'name': 'MPI_Barrier', 'type': 'function'}          8  1876752849
# 254        {'name': 'MPI_Barrier', 'type': 'function'}         64  2019302383
# 255        {'name': 'MPI_Barrier', 'type': 'function'}        512  2405902553
# 256        {'name': 'MPI_Barrier', 'type': 'function'}          2  2466704898
# 257        {'name': 'MPI_Barrier', 'type': 'function'}        128  2570818907
# 258        {'name': 'MPI_Barrier', 'type': 'function'}          4  2680675339
# 259        {'name': 'MPI_Barrier', 'type': 'function'}         64  2939914029
# 260        {'name': 'MPI_Barrier', 'type': 'function'}        256  2957797805
# 261        {'name': 'MPI_Barrier', 'type': 'function'}       1024  3113931281
# 262        {'name': 'MPI_Barrier', 'type': 'function'}         16  3265756731
# 263        {'name': 'MPI_Barrier', 'type': 'function'}        512  3472188329
# 264        {'name': 'MPI_Barrier', 'type': 'function'}         32  3947188472
# 265        {'name': 'MPI_Barrier', 'type': 'function'}         32  3950392994
# 266          {'name': 'MPI_Bcast', 'type': 'function'}        128    34514284
# 267          {'name': 'MPI_Bcast', 'type': 'function'}         16    51158898
# 268          {'name': 'MPI_Bcast', 'type': 'function'}          2   210478988
# 269          {'name': 'MPI_Bcast', 'type': 'function'}          8   389822904
# 270          {'name': 'MPI_Bcast', 'type': 'function'}          4  1161105437
# 271          {'name': 'MPI_Bcast', 'type': 'function'}        256  1656300721
# 272          {'name': 'MPI_Bcast', 'type': 'function'}          8  1876752849
# 273          {'name': 'MPI_Bcast', 'type': 'function'}         64  2019302383
# 274          {'name': 'MPI_Bcast', 'type': 'function'}        512  2405902553
# 275          {'name': 'MPI_Bcast', 'type': 'function'}          2  2466704898
# 276          {'name': 'MPI_Bcast', 'type': 'function'}        128  2570818907
# 277          {'name': 'MPI_Bcast', 'type': 'function'}          4  2680675339
# 278          {'name': 'MPI_Bcast', 'type': 'function'}         64  2939914029
# 279          {'name': 'MPI_Bcast', 'type': 'function'}        256  2957797805
# 280          {'name': 'MPI_Bcast', 'type': 'function'}       1024  3113931281
# 281          {'name': 'MPI_Bcast', 'type': 'function'}         16  3265756731
# 282          {'name': 'MPI_Bcast', 'type': 'function'}        512  3472188329
# 283          {'name': 'MPI_Bcast', 'type': 'function'}         32  3947188472
# 284          {'name': 'MPI_Bcast', 'type': 'function'}         32  3950392994
# 285               {'name': 'comp', 'type': 'function'}        128    34514284
# 286               {'name': 'comp', 'type': 'function'}         16    51158898
# 287               {'name': 'comp', 'type': 'function'}          2   210478988
# 288               {'name': 'comp', 'type': 'function'}          8   389822904
# 289               {'name': 'comp', 'type': 'function'}          4  1161105437
# 290               {'name': 'comp', 'type': 'function'}        256  1656300721
# 291               {'name': 'comp', 'type': 'function'}          8  1876752849
# 292               {'name': 'comp', 'type': 'function'}         64  2019302383
# 293               {'name': 'comp', 'type': 'function'}        512  2405902553
# 294               {'name': 'comp', 'type': 'function'}          2  2466704898
# 295               {'name': 'comp', 'type': 'function'}        128  2570818907
# 296               {'name': 'comp', 'type': 'function'}          4  2680675339
# 297               {'name': 'comp', 'type': 'function'}         64  2939914029
# 298               {'name': 'comp', 'type': 'function'}        256  2957797805
# 299               {'name': 'comp', 'type': 'function'}       1024  3113931281
# 300               {'name': 'comp', 'type': 'function'}         16  3265756731
# 301               {'name': 'comp', 'type': 'function'}        512  3472188329
# 302               {'name': 'comp', 'type': 'function'}         32  3947188472
# 303               {'name': 'comp', 'type': 'function'}         32  3950392994
# 304         {'name': 'comp_large', 'type': 'function'}        128    34514284
# 305         {'name': 'comp_large', 'type': 'function'}         16    51158898
# 306         {'name': 'comp_large', 'type': 'function'}          2   210478988
# 307         {'name': 'comp_large', 'type': 'function'}          8   389822904
# 308         {'name': 'comp_large', 'type': 'function'}          4  1161105437
# 309         {'name': 'comp_large', 'type': 'function'}        256  1656300721
# 310         {'name': 'comp_large', 'type': 'function'}          8  1876752849
# 311         {'name': 'comp_large', 'type': 'function'}         64  2019302383
# 312         {'name': 'comp_large', 'type': 'function'}        512  2405902553
# 313         {'name': 'comp_large', 'type': 'function'}          2  2466704898
# 314         {'name': 'comp_large', 'type': 'function'}        128  2570818907
# 315         {'name': 'comp_large', 'type': 'function'}          4  2680675339
# 316         {'name': 'comp_large', 'type': 'function'}         64  2939914029
# 317         {'name': 'comp_large', 'type': 'function'}        256  2957797805
# 318         {'name': 'comp_large', 'type': 'function'}       1024  3113931281
# 319         {'name': 'comp_large', 'type': 'function'}         16  3265756731
# 320         {'name': 'comp_large', 'type': 'function'}        512  3472188329
# 321         {'name': 'comp_large', 'type': 'function'}         32  3947188472
# 322         {'name': 'comp_large', 'type': 'function'}         32  3950392994
# 323  {'name': 'correctness_check', 'type': 'function'}        128    34514284
# 324  {'name': 'correctness_check', 'type': 'function'}         16    51158898
# 325  {'name': 'correctness_check', 'type': 'function'}          2   210478988
# 326  {'name': 'correctness_check', 'type': 'function'}          8   389822904
# 327  {'name': 'correctness_check', 'type': 'function'}          4  1161105437
# 328  {'name': 'correctness_check', 'type': 'function'}        256  1656300721
# 329  {'name': 'correctness_check', 'type': 'function'}          8  1876752849
# 330  {'name': 'correctness_check', 'type': 'function'}         64  2019302383
# 331  {'name': 'correctness_check', 'type': 'function'}        512  2405902553
# 332  {'name': 'correctness_check', 'type': 'function'}          2  2466704898
# 333  {'name': 'correctness_check', 'type': 'function'}        128  2570818907
# 334  {'name': 'correctness_check', 'type': 'function'}          4  2680675339
# 335  {'name': 'correctness_check', 'type': 'function'}         64  2939914029
# 336  {'name': 'correctness_check', 'type': 'function'}        256  2957797805
# 337  {'name': 'correctness_check', 'type': 'function'}       1024  3113931281
# 338  {'name': 'correctness_check', 'type': 'function'}         16  3265756731
# 339  {'name': 'correctness_check', 'type': 'function'}        512  3472188329
# 340  {'name': 'correctness_check', 'type': 'function'}         32  3947188472
# 341  {'name': 'correctness_check', 'type': 'function'}         32  3950392994
# 342  {'name': 'data_init_runtime', 'type': 'function'}        128    34514284
# 343  {'name': 'data_init_runtime', 'type': 'function'}         16    51158898
# 344  {'name': 'data_init_runtime', 'type': 'function'}          2   210478988
# 345  {'name': 'data_init_runtime', 'type': 'function'}          8   389822904
# 346  {'name': 'data_init_runtime', 'type': 'function'}          4  1161105437
# 347  {'name': 'data_init_runtime', 'type': 'function'}        256  1656300721
# 348  {'name': 'data_init_runtime', 'type': 'function'}          8  1876752849
# 349  {'name': 'data_init_runtime', 'type': 'function'}         64  2019302383
# 350  {'name': 'data_init_runtime', 'type': 'function'}        512  2405902553
# 351  {'name': 'data_init_runtime', 'type': 'function'}          2  2466704898
# 352  {'name': 'data_init_runtime', 'type': 'function'}        128  2570818907
# 353  {'name': 'data_init_runtime', 'type': 'function'}          4  2680675339
# 354  {'name': 'data_init_runtime', 'type': 'function'}         64  2939914029
# 355  {'name': 'data_init_runtime', 'type': 'function'}        256  2957797805
# 356  {'name': 'data_init_runtime', 'type': 'function'}       1024  3113931281
# 357  {'name': 'data_init_runtime', 'type': 'function'}         16  3265756731
# 358  {'name': 'data_init_runtime', 'type': 'function'}        512  3472188329
# 359  {'name': 'data_init_runtime', 'type': 'function'}         32  3947188472
# 360  {'name': 'data_init_runtime', 'type': 'function'}         32  3950392994
# 361         {'name': 'MPI_Gather', 'type': 'function'}        128    34514284
# 362         {'name': 'MPI_Gather', 'type': 'function'}         16    51158898
# 363         {'name': 'MPI_Gather', 'type': 'function'}          2   210478988
# 364         {'name': 'MPI_Gather', 'type': 'function'}          8   389822904
# 365         {'name': 'MPI_Gather', 'type': 'function'}          4  1161105437
# 366         {'name': 'MPI_Gather', 'type': 'function'}        256  1656300721
# 367         {'name': 'MPI_Gather', 'type': 'function'}          8  1876752849
# 368         {'name': 'MPI_Gather', 'type': 'function'}         64  2019302383
# 369         {'name': 'MPI_Gather', 'type': 'function'}        512  2405902553
# 370         {'name': 'MPI_Gather', 'type': 'function'}          2  2466704898
# 371         {'name': 'MPI_Gather', 'type': 'function'}        128  2570818907
# 372         {'name': 'MPI_Gather', 'type': 'function'}          4  2680675339
# 373         {'name': 'MPI_Gather', 'type': 'function'}         64  2939914029
# 374         {'name': 'MPI_Gather', 'type': 'function'}        256  2957797805
# 375         {'name': 'MPI_Gather', 'type': 'function'}       1024  3113931281
# 376         {'name': 'MPI_Gather', 'type': 'function'}         16  3265756731
# 377         {'name': 'MPI_Gather', 'type': 'function'}        512  3472188329
# 378         {'name': 'MPI_Gather', 'type': 'function'}         32  3947188472
# 379         {'name': 'MPI_Gather', 'type': 'function'}         32  3950392994
#
#       nid   spot.channel  Min time/rank  Max time/rank  Avg time/rank  \
# 0     1.0  regionprofile       2.162364       2.185724       2.174416
# 1     1.0  regionprofile       2.402589       2.402741       2.402685
# 2     1.0  regionprofile       2.432996       2.433015       2.433006
# 3     1.0  regionprofile       1.233312       1.234984       1.234233
# 4     1.0  regionprofile       1.514166       1.514255       1.514207
# 5     1.0  regionprofile       2.053408       2.322270       2.280886
# 6     1.0  regionprofile       2.139028       2.143197       2.142628
# 7     1.0  regionprofile       1.995686       2.037916       2.017470
# 8     1.0  regionprofile       2.211498       2.301872       2.264290
# 9     1.0  regionprofile       2.233422       2.233807       2.233614
# 10    1.0  regionprofile       1.863239       1.875734       1.869879
# 11    1.0  regionprofile       1.273293       1.273326       1.273316
# 12    1.0  regionprofile       2.075888       2.086001       2.080970
# 13    1.0  regionprofile       2.537286       5.033540       4.738822
# 14    1.0  regionprofile       2.668541       2.747921       2.702987
# 15    1.0  regionprofile       1.282120       1.284455       1.283653
# 16    1.0  regionprofile       2.203540       2.282527       2.254292
# 17    1.0  regionprofile       1.921291       1.928423       1.925055
# 18    1.0  regionprofile       2.451306       2.451619       2.451472
# 19   20.0  regionprofile       0.000233       0.119637       0.117308
# 20   20.0  regionprofile       0.000103       0.118858       0.111412
# 21   20.0  regionprofile       0.000084       0.114620       0.057352
# 22   20.0  regionprofile       0.000098       0.118783       0.103932
# 23   20.0  regionprofile       0.000078       0.117859       0.088260
# 24   20.0  regionprofile       0.000258       0.122947       0.121547
# 25   20.0  regionprofile       0.001032       0.117207       0.102655
# 26   20.0  regionprofile       0.000210       0.217442       0.211975
# 27   20.0  regionprofile       0.000181       0.127224       0.125753
# 28   20.0  regionprofile       0.000125       0.115533       0.057829
# 29   20.0  regionprofile       0.000139       0.119395       0.117109
# 30   20.0  regionprofile       0.000090       0.118849       0.089141
# 31   20.0  regionprofile       0.000244       0.120561       0.116887
# 32   20.0  regionprofile       0.000159       0.122085       0.120706
# 33   20.0  regionprofile       0.001648       0.122706       0.121522
# 34   20.0  regionprofile       0.000132       0.118853       0.110434
# 35   20.0  regionprofile       0.000220       0.156782       0.156143
# 36   20.0  regionprofile       0.000110       0.119472       0.115088
# 37   20.0  regionprofile       0.000102       0.118983       0.114648
# 38    3.0  regionprofile       0.015572       0.036020       0.026489
# 39    3.0  regionprofile       0.035009       0.035563       0.035512
# 40    3.0  regionprofile       0.000425       0.001556       0.000990
# 41    3.0  regionprofile       0.018251       0.018864       0.018572
# 42    3.0  regionprofile       0.017817       0.023156       0.019358
# 43    3.0  regionprofile       0.009371       0.092045       0.062450
# 44    3.0  regionprofile       0.015413       0.015934       0.015806
# 45    3.0  regionprofile       0.004979       0.030764       0.019053
# 46    3.0  regionprofile       0.016866       0.176636       0.104663
# 47    3.0  regionprofile       0.000837       0.004861       0.002849
# 48    3.0  regionprofile       0.005636       0.041476       0.026791
# 49    3.0  regionprofile       0.004721       0.005291       0.005117
# 50    3.0  regionprofile       0.012676       0.025841       0.019164
# 51    3.0  regionprofile       0.013878       1.044332       0.416876
# 52    3.0  regionprofile       0.017398       0.358503       0.203732
# 53    3.0  regionprofile       0.019248       0.021507       0.020129
# 54    3.0  regionprofile       0.010578       0.251902       0.162443
# 55    3.0  regionprofile       0.039087       0.045146       0.043585
# 56    3.0  regionprofile       0.038652       0.044085       0.042998
# 57   17.0  regionprofile       0.000004       0.000010       0.000004
# 58   17.0  regionprofile       0.000004       0.000015       0.000005
# 59   17.0  regionprofile       0.000004       0.000016       0.000010
# 60   17.0  regionprofile       0.000004       0.000012       0.000005
# 61   17.0  regionprofile       0.000004       0.000010       0.000006
# 62   17.0  regionprofile       0.000004       0.000011       0.000004
# 63   17.0  regionprofile       0.000004       0.000012       0.000005
# 64   17.0  regionprofile       0.000004       0.000024       0.000006
# 65   17.0  regionprofile       0.000004       0.000011       0.000004
# 66   17.0  regionprofile       0.000004       0.000019       0.000011
# 67   17.0  regionprofile       0.000004       0.000010       0.000004
# 68   17.0  regionprofile       0.000004       0.000011       0.000006
# 69   17.0  regionprofile       0.000004       0.000010       0.000004
# 70   17.0  regionprofile       0.000004       0.000011       0.000005
# 71   17.0  regionprofile       0.000004       0.000011       0.000004
# 72   17.0  regionprofile       0.000004       0.000010       0.000005
# 73   17.0  regionprofile       0.000004       0.000014       0.000005
# 74   17.0  regionprofile       0.000004       0.000010       0.000004
# 75   17.0  regionprofile       0.000004       0.000007       0.000004
# 76   19.0  regionprofile       0.000004       0.000005       0.000005
# 77   19.0  regionprofile       0.000004       0.000005       0.000005
# 78   19.0  regionprofile       0.000004       0.000005       0.000005
# 79   19.0  regionprofile       0.000004       0.000005       0.000005
# 80   19.0  regionprofile       0.000004       0.000005       0.000005
# 81   19.0  regionprofile       0.000004       0.000018       0.000005
# 82   19.0  regionprofile       0.000005       0.000007       0.000006
# 83   19.0  regionprofile       0.000004       0.000011       0.000006
# 84   19.0  regionprofile       0.000004       0.000014       0.000005
# 85   19.0  regionprofile       0.000005       0.000006       0.000005
# 86   19.0  regionprofile       0.000004       0.000009       0.000004
# 87   19.0  regionprofile       0.000004       0.000005       0.000005
# 88   19.0  regionprofile       0.000004       0.000006       0.000005
# 89   19.0  regionprofile       0.000004       0.000011       0.000005
# 90   19.0  regionprofile       0.000004       0.000010       0.000005
# 91   19.0  regionprofile       0.000004       0.000005       0.000005
# 92   19.0  regionprofile       0.000004       0.000029       0.000005
# 93   19.0  regionprofile       0.000004       0.000005       0.000005
# 94   19.0  regionprofile       0.000004       0.000005       0.000005
# 95    2.0  regionprofile       0.000028       0.000266       0.000106
# 96    2.0  regionprofile       0.000028       0.000056       0.000036
# 97    2.0  regionprofile       0.000046       0.000068       0.000057
# 98    2.0  regionprofile       0.000028       0.000041       0.000031
# 99    2.0  regionprofile       0.000028       0.000050       0.000034
# 100   2.0  regionprofile       0.000027       0.000182       0.000037
# 101   2.0  regionprofile       0.000028       0.000061       0.000051
# 102   2.0  regionprofile       0.000027       0.000094       0.000038
# 103   2.0  regionprofile       0.000027       0.000498       0.000101
# 104   2.0  regionprofile       0.000032       0.000043       0.000038
# 105   2.0  regionprofile       0.000027       0.000252       0.000039
# 106   2.0  regionprofile       0.000027       0.000050       0.000038
# 107   2.0  regionprofile       0.000028       0.000307       0.000119
# 108   2.0  regionprofile       0.000027       0.000289       0.000041
# 109   2.0  regionprofile       0.000027       0.000539       0.000103
# 110   2.0  regionprofile       0.000028       0.000184       0.000041
# 111   2.0  regionprofile       0.000027       0.000077       0.000033
# 112   2.0  regionprofile       0.000028       0.000057       0.000035
# 113   2.0  regionprofile       0.000027       0.000069       0.000037
# 114  18.0  regionprofile       0.000005       0.000013       0.000006
# 115  18.0  regionprofile       0.000005       0.000006       0.000006
# 116  18.0  regionprofile       0.000005       0.000006       0.000006
# 117  18.0  regionprofile       0.000005       0.000007       0.000006
# 118  18.0  regionprofile       0.000005       0.000006       0.000006
# 119  18.0  regionprofile       0.000005       0.000017       0.000007
# 120  18.0  regionprofile       0.000005       0.000006       0.000006
# 121  18.0  regionprofile       0.000005       0.000024       0.000009
# 122  18.0  regionprofile       0.000005       0.000016       0.000006
# 123  18.0  regionprofile       0.000008       0.000010       0.000009
# 124  18.0  regionprofile       0.000005       0.000007       0.000005
# 125  18.0  regionprofile       0.000006       0.000006       0.000006
# 126  18.0  regionprofile       0.000005       0.000008       0.000006
# 127  18.0  regionprofile       0.000005       0.000023       0.000007
# 128  18.0  regionprofile       0.000005       0.000025       0.000006
# 129  18.0  regionprofile       0.000005       0.000007       0.000006
# 130  18.0  regionprofile       0.000005       0.000019       0.000007
# 131  18.0  regionprofile       0.000005       0.000006       0.000006
# 132  18.0  regionprofile       0.000005       0.000006       0.000006
# 133   6.0  regionprofile       0.041123       0.066297       0.048419
# 134   6.0  regionprofile       0.028380       0.046786       0.043955
# 135   6.0  regionprofile       0.008646       0.031626       0.020136
# 136   6.0  regionprofile       0.043029       0.086989       0.068741
# 137   6.0  regionprofile       0.025428       0.064597       0.051334
# 138   6.0  regionprofile       0.018904       0.030916       0.028702
# 139   6.0  regionprofile       0.014903       0.027468       0.025116
# 140   6.0  regionprofile       0.061195       0.119902       0.096732
# 141   6.0  regionprofile       0.020882       0.033717       0.029962
# 142   6.0  regionprofile       0.011490       0.018192       0.014841
# 143   6.0  regionprofile       0.047612       0.083544       0.061117
# 144   6.0  regionprofile       0.014619       0.028064       0.023341
# 145   6.0  regionprofile       0.021766       0.037118       0.029502
# 146   6.0  regionprofile       0.021937       0.058025       0.050243
# 147   6.0  regionprofile       0.021919       0.038668       0.034358
# 148   6.0  regionprofile       0.038766       0.080436       0.064989
# 149   6.0  regionprofile       0.029176       0.059687       0.052520
# 150   6.0  regionprofile       0.037689       0.074461       0.061110
# 151   6.0  regionprofile       0.013708       0.031446       0.029323
# 152   9.0  regionprofile       0.007130       0.032088       0.014393
# 153   9.0  regionprofile       0.005248       0.020962       0.007812
# 154   9.0  regionprofile       0.008334       0.018655       0.013494
# 155   9.0  regionprofile       0.007656       0.012307       0.010146
# 156   9.0  regionprofile       0.009582       0.015324       0.012211
# 157   9.0  regionprofile       0.002441       0.010420       0.004558
# 158   9.0  regionprofile       0.007743       0.010953       0.008750
# 159   9.0  regionprofile       0.005390       0.020010       0.010678
# 160   9.0  regionprofile       0.003796       0.015342       0.006475
# 161   9.0  regionprofile       0.007043       0.010198       0.008620
# 162   9.0  regionprofile       0.003128       0.038906       0.011912
# 163   9.0  regionprofile       0.007035       0.012310       0.009937
# 164   9.0  regionprofile       0.005100       0.019417       0.009707
# 165   9.0  regionprofile       0.002647       0.009992       0.005341
# 166   9.0  regionprofile       0.007502       0.012222       0.009407
# 167   9.0  regionprofile       0.005131       0.012005       0.007676
# 168   9.0  regionprofile       0.004108       0.018852       0.006278
# 169   9.0  regionprofile       0.003506       0.009992       0.006364
# 170   9.0  regionprofile       0.003961       0.010617       0.006165
# 171  15.0  regionprofile       0.000021       0.002264       0.001352
# 172  15.0  regionprofile       0.000343       0.002874       0.000511
# 173  15.0  regionprofile       0.001464       0.002925       0.002195
# 174  15.0  regionprofile       0.000451       0.003315       0.000822
# 175  15.0  regionprofile       0.000833       0.003174       0.001435
# 176  15.0  regionprofile       0.000012       0.005028       0.000036
# 177  15.0  regionprofile       0.000428       0.003275       0.000796
# 178  15.0  regionprofile       0.000067       0.004388       0.002163
# 179  15.0  regionprofile       0.000010       0.009309       0.000186
# 180  15.0  regionprofile       0.001431       0.002954       0.002192
# 181  15.0  regionprofile       0.000023       0.002268       0.001353
# 182  15.0  regionprofile       0.000812       0.003310       0.001442
# 183  15.0  regionprofile       0.000025       0.003465       0.001667
# 184  15.0  regionprofile       0.000015       0.004278       0.000041
# 185  15.0  regionprofile       0.000009       0.004356       0.000078
# 186  15.0  regionprofile       0.000336       0.002747       0.000506
# 187  15.0  regionprofile       0.000010       0.012187       0.000236
# 188  15.0  regionprofile       0.000165       0.003134       0.000303
# 189  15.0  regionprofile       0.000168       0.003094       0.000287
# 190  10.0  regionprofile       0.000892       0.006458       0.001550
# 191  10.0  regionprofile       0.000415       0.002996       0.001913
# 192  10.0  regionprofile       0.002994       0.003070       0.003032
# 193  10.0  regionprofile       0.000827       0.003702       0.002475
# 194  10.0  regionprofile       0.001230       0.003394       0.002334
# 195  10.0  regionprofile       0.000172       0.003262       0.001852
# 196  10.0  regionprofile       0.001303       0.003950       0.002838
# 197  10.0  regionprofile       0.000189       0.002629       0.001792
# 198  10.0  regionprofile       0.001318       0.004243       0.003059
# 199  10.0  regionprofile       0.002636       0.002779       0.002708
# 200  10.0  regionprofile       0.000150       0.002755       0.001692
# 201  10.0  regionprofile       0.001768       0.003274       0.002649
# 202  10.0  regionprofile       0.000810       0.003253       0.002189
# 203  10.0  regionprofile       0.000090       0.003403       0.001915
# 204  10.0  regionprofile       0.004732       0.006596       0.006026
# 205  10.0  regionprofile       0.000404       0.002804       0.001788
# 206  10.0  regionprofile       0.001039       0.004205       0.002974
# 207  10.0  regionprofile       0.000235       0.003838       0.002125
# 208  10.0  regionprofile       0.000245       0.004593       0.002582
# 209  13.0  regionprofile       0.002190       0.028427       0.011264
# 210  13.0  regionprofile       0.003577       0.017450       0.005244
# 211  13.0  regionprofile       0.002271       0.014129       0.008200
# 212  13.0  regionprofile       0.004420       0.009507       0.006731
# 213  13.0  regionprofile       0.003818       0.012354       0.008374
# 214  13.0  regionprofile       0.001748       0.008034       0.002405
# 215  13.0  regionprofile       0.003948       0.006503       0.005024
# 216  13.0  regionprofile       0.002807       0.013353       0.006441
# 217  13.0  regionprofile       0.001436       0.004546       0.002907
# 218  13.0  regionprofile       0.002915       0.004400       0.003658
# 219  13.0  regionprofile       0.001882       0.035097       0.008645
# 220  13.0  regionprofile       0.004116       0.008965       0.005764
# 221  13.0  regionprofile       0.002312       0.013311       0.005662
# 222  13.0  regionprofile       0.001874       0.005335       0.003091
# 223  13.0  regionprofile       0.001221       0.003912       0.002904
# 224  13.0  regionprofile       0.003305       0.009260       0.005250
# 225  13.0  regionprofile       0.001427       0.005143       0.002699
# 226  13.0  regionprofile       0.002332       0.009374       0.003776
# 227  13.0  regionprofile       0.002727       0.007805       0.003132
# 228   7.0  regionprofile       0.010966       0.058663       0.033645
# 229   7.0  regionprofile       0.018595       0.040519       0.035958
# 230   7.0  regionprofile       0.000247       0.012907       0.006577
# 231   7.0  regionprofile       0.033166       0.076854       0.058447
# 232   7.0  regionprofile       0.015768       0.054780       0.039041
# ...
# 54      MPI_Comm_split  1perturbed     4194304
# 55      MPI_Comm_split  1perturbed     4194304
# 56      MPI_Comm_split      random     4194304
# 57        MPI_Finalize      random     4194304
# 58        MPI_Finalize      random     4194304
# 59        MPI_Finalize      random     4194304
# 60        MPI_Finalize  1perturbed     4194304
# 61        MPI_Finalize  1perturbed     4194304
# 62        MPI_Finalize      random     4194304
# 63        MPI_Finalize      random     4194304
# 64        MPI_Finalize  1perturbed     4194304
# 65        MPI_Finalize      random     4194304
# 66        MPI_Finalize  1perturbed     4194304
# 67        MPI_Finalize  1perturbed     4194304
# 68        MPI_Finalize      random     4194304
# 69        MPI_Finalize      random     4194304
# 70        MPI_Finalize  1perturbed     4194304
# 71        MPI_Finalize      random     4194304
# 72        MPI_Finalize  1perturbed     4194304
# 73        MPI_Finalize  1perturbed     4194304
# 74        MPI_Finalize  1perturbed     4194304
# 75        MPI_Finalize      random     4194304
# 76       MPI_Finalized      random     4194304
# 77       MPI_Finalized      random     4194304
# 78       MPI_Finalized      random     4194304
# 79       MPI_Finalized  1perturbed     4194304
# 80       MPI_Finalized  1perturbed     4194304
# 81       MPI_Finalized      random     4194304
# 82       MPI_Finalized      random     4194304
# 83       MPI_Finalized  1perturbed     4194304
# 84       MPI_Finalized      random     4194304
# 85       MPI_Finalized  1perturbed     4194304
# 86       MPI_Finalized  1perturbed     4194304
# 87       MPI_Finalized      random     4194304
# 88       MPI_Finalized      random     4194304
# 89       MPI_Finalized  1perturbed     4194304
# 90       MPI_Finalized      random     4194304
# 91       MPI_Finalized  1perturbed     4194304
# 92       MPI_Finalized  1perturbed     4194304
# 93       MPI_Finalized  1perturbed     4194304
# 94       MPI_Finalized      random     4194304
# 95            MPI_Init      random     4194304
# 96            MPI_Init      random     4194304
# 97            MPI_Init      random     4194304
# 98            MPI_Init  1perturbed     4194304
# 99            MPI_Init  1perturbed     4194304
# 100           MPI_Init      random     4194304
# 101           MPI_Init      random     4194304
# 102           MPI_Init  1perturbed     4194304
# 103           MPI_Init      random     4194304
# 104           MPI_Init  1perturbed     4194304
# 105           MPI_Init  1perturbed     4194304
# 106           MPI_Init      random     4194304
# 107           MPI_Init      random     4194304
# 108           MPI_Init  1perturbed     4194304
# 109           MPI_Init      random     4194304
# 110           MPI_Init  1perturbed     4194304
# 111           MPI_Init  1perturbed     4194304
# 112           MPI_Init  1perturbed     4194304
# 113           MPI_Init      random     4194304
# 114    MPI_Initialized      random     4194304
# 115    MPI_Initialized      random     4194304
# 116    MPI_Initialized      random     4194304
# 117    MPI_Initialized  1perturbed     4194304
# 118    MPI_Initialized  1perturbed     4194304
# 119    MPI_Initialized      random     4194304
# 120    MPI_Initialized      random     4194304
# 121    MPI_Initialized  1perturbed     4194304
# 122    MPI_Initialized      random     4194304
# 123    MPI_Initialized  1perturbed     4194304
# 124    MPI_Initialized  1perturbed     4194304
# 125    MPI_Initialized      random     4194304
# 126    MPI_Initialized      random     4194304
# 127    MPI_Initialized  1perturbed     4194304
# 128    MPI_Initialized      random     4194304
# 129    MPI_Initialized  1perturbed     4194304
# 130    MPI_Initialized  1perturbed     4194304
# 131    MPI_Initialized  1perturbed     4194304
# 132    MPI_Initialized      random     4194304
# 133               comm      random     4194304
# 134               comm      random     4194304
# 135               comm      random     4194304
# 136               comm  1perturbed     4194304
# 137               comm  1perturbed     4194304
# 138               comm      random     4194304
# 139               comm      random     4194304
# 140               comm  1perturbed     4194304
# 141               comm      random     4194304
# 142               comm  1perturbed     4194304
# 143               comm  1perturbed     4194304
# 144               comm      random     4194304
# 145               comm      random     4194304
# 146               comm  1perturbed     4194304
# 147               comm      random     4194304
# 148               comm  1perturbed     4194304
# 149               comm  1perturbed     4194304
# 150               comm  1perturbed     4194304
# 151               comm      random     4194304
# 152         comm_large      random     4194304
# 153         comm_large      random     4194304
# 154         comm_large      random     4194304
# 155         comm_large  1perturbed     4194304
# 156         comm_large  1perturbed     4194304
# 157         comm_large      random     4194304
# 158         comm_large      random     4194304
# 159         comm_large  1perturbed     4194304
# 160         comm_large      random     4194304
# 161         comm_large  1perturbed     4194304
# 162         comm_large  1perturbed     4194304
# 163         comm_large      random     4194304
# 164         comm_large      random     4194304
# 165         comm_large  1perturbed     4194304
# 166         comm_large      random     4194304
# 167         comm_large  1perturbed     4194304
# 168         comm_large  1perturbed     4194304
# 169         comm_large  1perturbed     4194304
# 170         comm_large      random     4194304
# 171         MPI_Gather      random     4194304
# 172         MPI_Gather      random     4194304
# 173         MPI_Gather      random     4194304
# 174         MPI_Gather  1perturbed     4194304
# 175         MPI_Gather  1perturbed     4194304
# 176         MPI_Gather      random     4194304
# 177         MPI_Gather      random     4194304
# 178         MPI_Gather  1perturbed     4194304
# 179         MPI_Gather      random     4194304
# 180         MPI_Gather  1perturbed     4194304
# 181         MPI_Gather  1perturbed     4194304
# 182         MPI_Gather      random     4194304
# 183         MPI_Gather      random     4194304
# 184         MPI_Gather  1perturbed     4194304
# 185         MPI_Gather      random     4194304
# 186         MPI_Gather  1perturbed     4194304
# 187         MPI_Gather  1perturbed     4194304
# 188         MPI_Gather  1perturbed     4194304
# 189         MPI_Gather      random     4194304
# 190        MPI_Scatter      random     4194304
# 191        MPI_Scatter      random     4194304
# 192        MPI_Scatter      random     4194304
# 193        MPI_Scatter  1perturbed     4194304
# 194        MPI_Scatter  1perturbed     4194304
# 195        MPI_Scatter      random     4194304
# 196        MPI_Scatter      random     4194304
# 197        MPI_Scatter  1perturbed     4194304
# 198        MPI_Scatter      random     4194304
# 199        MPI_Scatter  1perturbed     4194304
# 200        MPI_Scatter  1perturbed     4194304
# 201        MPI_Scatter      random     4194304
# 202        MPI_Scatter      random     4194304
# 203        MPI_Scatter  1perturbed     4194304
# 204        MPI_Scatter      random     4194304
# 205        MPI_Scatter  1perturbed     4194304
# 206        MPI_Scatter  1perturbed     4194304
# 207        MPI_Scatter  1perturbed     4194304
# 208        MPI_Scatter      random     4194304
# 209       MPI_Sendrecv      random     4194304
# 210       MPI_Sendrecv      random     4194304
# 211       MPI_Sendrecv      random     4194304
# 212       MPI_Sendrecv  1perturbed     4194304
# 213       MPI_Sendrecv  1perturbed     4194304
# 214       MPI_Sendrecv      random     4194304
# 215       MPI_Sendrecv      random     4194304
# 216       MPI_Sendrecv  1perturbed     4194304
# 217       MPI_Sendrecv      random     4194304
# 218       MPI_Sendrecv  1perturbed     4194304
# 219       MPI_Sendrecv  1perturbed     4194304
# 220       MPI_Sendrecv      random     4194304
# 221       MPI_Sendrecv      random     4194304
# 222       MPI_Sendrecv  1perturbed     4194304
# 223       MPI_Sendrecv      random     4194304
# 224       MPI_Sendrecv  1perturbed     4194304
# 225       MPI_Sendrecv  1perturbed     4194304
# 226       MPI_Sendrecv  1perturbed     4194304
# 227       MPI_Sendrecv      random     4194304
# 228         comm_small      random     4194304
# 229         comm_small      random     4194304
# 230         comm_small      random     4194304
# 231         comm_small  1perturbed     4194304
# 232         comm_small  1perturbed     4194304
# 233         comm_small      random     4194304
# 234         comm_small      random     4194304
# 235         comm_small  1perturbed     4194304
# 236         comm_small      random     4194304
# 237         comm_small  1perturbed     4194304
# 238         comm_small  1perturbed     4194304
# 239         comm_small      random     4194304
# 240         comm_small      random     4194304
# 241         comm_small  1perturbed     4194304
# 242         comm_small      random     4194304
# 243         comm_small  1perturbed     4194304
# 244         comm_small  1perturbed     4194304
# 245         comm_small  1perturbed     4194304
# 246         comm_small      random     4194304
# 247        MPI_Barrier      random     4194304
# 248        MPI_Barrier      random     4194304
# 249        MPI_Barrier      random     4194304
# 250        MPI_Barrier  1perturbed     4194304
# 251        MPI_Barrier  1perturbed     4194304
# 252        MPI_Barrier      random     4194304
# 253        MPI_Barrier      random     4194304
# 254        MPI_Barrier  1perturbed     4194304
# 255        MPI_Barrier      random     4194304
# 256        MPI_Barrier  1perturbed     4194304
# 257        MPI_Barrier  1perturbed     4194304
# 258        MPI_Barrier      random     4194304
# 259        MPI_Barrier      random     4194304
# 260        MPI_Barrier  1perturbed     4194304
# 261        MPI_Barrier      random     4194304
# 262        MPI_Barrier  1perturbed     4194304
# 263        MPI_Barrier  1perturbed     4194304
# 264        MPI_Barrier  1perturbed     4194304
# 265        MPI_Barrier      random     4194304
# 266          MPI_Bcast      random     4194304
# 267          MPI_Bcast      random     4194304
# 268          MPI_Bcast      random     4194304
# 269          MPI_Bcast  1perturbed     4194304
# 270          MPI_Bcast  1perturbed     4194304
# 271          MPI_Bcast      random     4194304
# 272          MPI_Bcast      random     4194304
# 273          MPI_Bcast  1perturbed     4194304
# 274          MPI_Bcast      random     4194304
# 275          MPI_Bcast  1perturbed     4194304
# 276          MPI_Bcast  1perturbed     4194304
# 277          MPI_Bcast      random     4194304
# 278          MPI_Bcast      random     4194304
# 279          MPI_Bcast  1perturbed     4194304
# 280          MPI_Bcast      random     4194304
# 281          MPI_Bcast  1perturbed     4194304
# 282          MPI_Bcast  1perturbed     4194304
# 283          MPI_Bcast  1perturbed     4194304
# 284          MPI_Bcast      random     4194304
# 285               comp      random     4194304
# 286               comp      random     4194304
# 287               comp      random     4194304
# 288               comp  1perturbed     4194304
# 289               comp  1perturbed     4194304
# 290               comp      random     4194304
# 291               comp      random     4194304
# 292               comp  1perturbed     4194304
# 293               comp      random     4194304
# 294               comp  1perturbed     4194304
# 295               comp  1perturbed     4194304
# 296               comp      random     4194304
# 297               comp      random     4194304
# 298               comp  1perturbed     4194304
# 299               comp      random     4194304
# 300               comp  1perturbed     4194304
# 301               comp  1perturbed     4194304
# 302               comp  1perturbed     4194304
# 303               comp      random     4194304
# 304         comp_large      random     4194304
# 305         comp_large      random     4194304
# 306         comp_large      random     4194304
# 307         comp_large  1perturbed     4194304
# 308         comp_large  1perturbed     4194304
# 309         comp_large      random     4194304
# 310         comp_large      random     4194304
# 311         comp_large  1perturbed     4194304
# 312         comp_large      random     4194304
# 313         comp_large  1perturbed     4194304
# 314         comp_large  1perturbed     4194304
# 315         comp_large      random     4194304
# 316         comp_large      random     4194304
# 317         comp_large  1perturbed     4194304
# 318         comp_large      random     4194304
# 319         comp_large  1perturbed     4194304
# 320         comp_large  1perturbed     4194304
# 321         comp_large  1perturbed     4194304
# 322         comp_large      random     4194304
# 323  correctness_check      random     4194304
# 324  correctness_check      random     4194304
# 325  correctness_check      random     4194304
# 326  correctness_check  1perturbed     4194304
# 327  correctness_check  1perturbed     4194304
# 328  correctness_check      random     4194304
# 329  correctness_check      random     4194304
# 330  correctness_check  1perturbed     4194304
# 331  correctness_check      random     4194304
# 332  correctness_check  1perturbed     4194304
# 333  correctness_check  1perturbed     4194304
# 334  correctness_check      random     4194304
# 335  correctness_check      random     4194304
# 336  correctness_check  1perturbed     4194304
# 337  correctness_check      random     4194304
# 338  correctness_check  1perturbed     4194304
# 339  correctness_check  1perturbed     4194304
# 340  correctness_check  1perturbed     4194304
# 341  correctness_check      random     4194304
# 342  data_init_runtime      random     4194304
# 343  data_init_runtime      random     4194304
# 344  data_init_runtime      random     4194304
# 345  data_init_runtime  1perturbed     4194304
# 346  data_init_runtime  1perturbed     4194304
# 347  data_init_runtime      random     4194304
# 348  data_init_runtime      random     4194304
# 349  data_init_runtime  1perturbed     4194304
# 350  data_init_runtime      random     4194304
# 351  data_init_runtime  1perturbed     4194304
# 352  data_init_runtime  1perturbed     4194304
# 353  data_init_runtime      random     4194304
# 354  data_init_runtime      random     4194304
# 355  data_init_runtime  1perturbed     4194304
# 356  data_init_runtime      random     4194304
# 357  data_init_runtime  1perturbed     4194304
# 358  data_init_runtime  1perturbed     4194304
# 359  data_init_runtime  1perturbed     4194304
# 360  data_init_runtime      random     4194304
# 361         MPI_Gather      random     4194304
# 362         MPI_Gather      random     4194304
# 363         MPI_Gather      random     4194304
# 364         MPI_Gather  1perturbed     4194304
# 365         MPI_Gather  1perturbed     4194304
# 366         MPI_Gather      random     4194304
# 367         MPI_Gather      random     4194304
# 368         MPI_Gather  1perturbed     4194304
# 369         MPI_Gather      random     4194304
# 370         MPI_Gather  1perturbed     4194304
# 371         MPI_Gather  1perturbed     4194304
# 372         MPI_Gather      random     4194304
# 373         MPI_Gather      random     4194304
# 374         MPI_Gather  1perturbed     4194304
# 375         MPI_Gather      random     4194304
# 376         MPI_Gather  1perturbed     4194304
# 377         MPI_Gather  1perturbed     4194304
# 378         MPI_Gather  1perturbed     4194304
# 379         MPI_Gather      random     4194304
