# %%
import sys
from glob import glob
import matplotlib.pyplot as plt
import pandas as pd
import thicket as th
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
tk = th.Thicket.from_caliperreader(glob("SpeedupSample/*.cali"))
# Out:
# (1/2) Reading Files: 100%|██████████| 36/36 [00:00<00:00, 60.18it/s]
# (2/2) Creating Thicket: 100%|██████████| 35/35 [00:00<00:00, 656.00it/s]
# /home/alex/Project_2024/new_env/lib/python3.12/site-packages/thicket/ensemble.py:409: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].replace({numerical_fill_value: None}, inplace=True)

# %%
tk.metadata.head()
# Out:
#           cali.caliper.version  mpi.world.size  \
# profile
# 71036787                2.11.0              16
# 295533304               2.11.0               8
# 430275413               2.11.0               4
# 566693142               2.11.0               8
# 613114193               2.11.0              16
#
#                                                 spot.metrics  \
# profile
# 71036787   min#inclusive#sum#time.duration,max#inclusive#...
# 295533304  min#inclusive#sum#time.duration,max#inclusive#...
# 430275413  min#inclusive#sum#time.duration,max#inclusive#...
# 566693142  min#inclusive#sum#time.duration,max#inclusive#...
# 613114193  min#inclusive#sum#time.duration,max#inclusive#...
#
#           spot.timeseries.metrics  spot.format.version  \
# profile
# 71036787                                             2
# 295533304                                            2
# 430275413                                            2
# 566693142                                            2
# 613114193                                            2
#
#                                                 spot.options  spot.channels  \
# profile
# 71036787   time.variance,profile.mpi,node.order,region.co...  regionprofile
# 295533304  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 430275413  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 566693142  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 613114193  time.variance,profile.mpi,node.order,region.co...  regionprofile
#
#           cali.channel spot:node.order  \
# profile
# 71036787          spot            true
# 295533304         spot            true
# 430275413         spot            true
# 566693142         spot            true
# 613114193         spot            true
#
#                                       spot:output spot:profile.mpi  \
# profile
# 71036787      p16-a268435456-ssample-isorted.cali             true
# 295533304      p8-a268435456-ssample-isorted.cali             true
# 430275413  p4-a268435456-ssample-i1perturbed.cali             true
# 566693142  p8-a268435456-ssample-i1perturbed.cali             true
# 613114193    p16-a268435456-ssample-ireverse.cali             true
#
#           spot:region.count spot:time.exclusive spot:time.variance  \
# profile
# 71036787               true                true               true
# 295533304              true                true               true
# 430275413              true                true               true
# 566693142              true                true               true
# 613114193              true                true               true
#
#            launchdate                                          libraries  \
# profile
# 71036787   1729585098  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 295533304  1729585098  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 430275413  1729585156  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 566693142  1729585156  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 613114193  1729585156  [/scratch/group/csce435-f24/Caliper/caliper/li...
#
#                                            cmdline cluster algorithm  \
# profile
# 71036787       [./main, 268435456, sample, sorted]       c    sample
# 295533304      [./main, 268435456, sample, sorted]       c    sample
# 430275413  [./main, 268435456, sample, 1perturbed]       c    sample
# 566693142  [./main, 268435456, sample, 1perturbed]       c    sample
# 613114193     [./main, 268435456, sample, reverse]       c    sample
#
#           programming_model data_type  size_of_data_type  input_size  \
# profile
# 71036787                mpi       int                  4   268435456
# 295533304               mpi       int                  4   268435456
# 430275413               mpi       int                  4   268435456
# 566693142               mpi       int                  4   268435456
# 613114193               mpi       int                  4   268435456
#
#            input_type  num_procs  group_num implementation_source scalability
# profile
# 71036787       sorted         16          8                online      strong
# 295533304      sorted          8          8                online      strong
# 430275413  1perturbed          4          8                online      strong
# 566693142  1perturbed          8          8                online      strong
# 613114193     reverse         16          8                online      strong

# %%
print(tk.tree(metric_column="Avg time/rank"))
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2024.1.0
#
# 22.468 main
# ├─ 7.019 MPI_Comm_dup
# ├─ 0.021 MPI_Comm_split
# ├─ 0.000 MPI_Finalize
# ├─ 0.000 MPI_Finalized
# ├─ 0.000 MPI_Init
# ├─ 0.000 MPI_Initialized
# ├─ 1.592 comm
# │  ├─ 0.473 comm_large
# │  │  ├─ 0.137 MPI_Alltoall
# │  │  ├─ 0.021 MPI_Alltoallv
# │  │  ├─ 0.015 MPI_Gather
# │  │  ├─ 0.164 MPI_Gatherv
# │  │  └─ 0.136 MPI_Scatter
# │  └─ 1.118 comm_small
# │     └─ 1.118 MPI_Bcast
# ├─ 11.915 comp
# │  ├─ 11.836 comp_large
# │  └─ 0.079 comp_small
# ├─ 0.461 correctness_check
# └─ 0.499 data_init_runtime
#    └─ 0.194 MPI_Gather
#
# Legend (Metric: Avg time/rank Min: 0.00 Max: 22.47 indices: {'profile': np.int64(71036787)})
# █ 20.22 - 22.47
# █ 15.73 - 20.22
# █ 11.23 - 15.73
# █ 6.74 - 11.23
# █ 2.25 - 6.74
# █ 0.00 - 2.25
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
tk.metadata_column_to_perfdata("num_procs")
tk.metadata_column_to_perfdata("input_type")
tk.metadata_column_to_perfdata("input_size")
tk.metadata_column_to_perfdata("algorithm")
tk.dataframe = tk.dataframe.reset_index()
tk.dataframe.head()
# Out:
#                                    node    profile  nid   spot.channel  \
# 0  {'name': 'main', 'type': 'function'}   71036787  1.0  regionprofile
# 1  {'name': 'main', 'type': 'function'}  295533304  1.0  regionprofile
# 2  {'name': 'main', 'type': 'function'}  430275413  1.0  regionprofile
# 3  {'name': 'main', 'type': 'function'}  566693142  1.0  regionprofile
# 4  {'name': 'main', 'type': 'function'}  613114193  1.0  regionprofile
#
#    Min time/rank  Max time/rank  Avg time/rank  Total time  \
# 0      22.466549      22.468385      22.467732  359.483709
# 1      50.932230      50.940188      50.934255  407.474042
# 2     176.671304     176.676163     176.672989  706.691954
# 3      93.894051      93.894873      93.894757  751.158057
# 4      21.324917      21.327365      21.326578  341.225253
#
#    Variance time/rank  Min time/rank (exc)  Max time/rank (exc)  \
# 0            0.000001             0.955482             0.964525
# 1            0.000007             0.762299             0.785315
# 2            0.000004             0.774071             0.785393
# 3            0.000000             1.055902             1.062604
# 4            0.000001             0.950811             0.962881
#
#    Avg time/rank (exc)  Total time (exc)  Calls/rank (min)  Calls/rank (avg)  \
# 0             0.961141         15.378260               NaN               NaN
# 1             0.778949          6.231593               NaN               NaN
# 2             0.779442          3.117769               NaN               NaN
# 3             1.060012          8.480099               NaN               NaN
# 4             0.960180         15.362883               NaN               NaN
#
#    Calls/rank (max)  Calls/rank (total)  name  num_procs  input_type  \
# 0               NaN                 NaN  main         16      sorted
# 1               NaN                 NaN  main          8      sorted
# 2               NaN                 NaN  main          4  1perturbed
# 3               NaN                 NaN  main          8  1perturbed
# 4               NaN                 NaN  main         16     reverse
#
#    input_size algorithm
# 0   268435456    sample
# 1   268435456    sample
# 2   268435456    sample
# 3   268435456    sample
# 4   268435456    sample

# %%
def plot_pandas(df, title, xlabel, ylabel):
    plot = df.plot(kind="line",
    marker='o',
    title=title,
    xlabel=xlabel,
    ylabel=ylabel,
    figsize=(15,7)
    )
    return plot

# %%
import os

input_sizes = [268435456] # Largest problem size
input_types = ["sorted", "reverse", "1perturbed", "random"]

# Change "type_selector" to the index of what you want to measure
time_types = ["Min time/rank", "Max time/rank", "Avg time/rank", "Total time", "Variance time/rank"]
file_output_label = ["min", "max", "avg", "total", "variance"]
type_selector = 4

# Prepare output folder for plots
output_dir = '../plot_outputs'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Function to create strong scaling speedup plots with 2x2 subplots
def plot_speedup(tk, input_types):
    for node in tk.graph.traverse():
        node_name = node.frame['name']
        if (node_name == 'comp_large') or (node_name == 'comm') or (node_name == 'main'):
            fig, axs = plt.subplots(2, 2, figsize=(12, 12))
            
            axs = axs.flatten()
            for idx, input_type in enumerate(input_types):
                ax = axs[idx]
                
                # Add node filter to baseline calculation
                baseline_time = tk.dataframe[
                    (tk.dataframe["num_procs"] == 2) & 
                    (tk.dataframe["input_type"] == input_type) &
                    (tk.dataframe['node'] == node)  # Added node filter
                ][time_types[type_selector]].values[0] * 2
                
                for input_size in input_sizes:
                    data = tk.dataframe[
                        (tk.dataframe["input_type"] == input_type) & 
                        (tk.dataframe["input_size"] == input_size) & 
                        (tk.dataframe['node'] == node)
                    ]
                    data = data.sort_values(by="num_procs")
                    
                    speedup = baseline_time / data[time_types[type_selector]]
                    ax.plot(data["num_procs"], speedup, marker='o', 
                           label=f'Input Size {input_size} on {node_name}')
                
                ax.set_title(f'Strong Scaling Speedup for {input_type} on {node_name} [{time_types[type_selector]}]')
                ax.set_xlabel('Number of Processors')
                ax.set_ylabel('Speedup')
                ax.legend()
            
            for j in range(idx + 1, len(axs)):
                fig.delaxes(axs[j])
            
            plt.tight_layout()
            filename = f'speedup_{file_output_label[type_selector]}_{input_type}_{node_name}_size{input_size}.png'
            filepath = os.path.join(output_dir, filename)
            plt.savefig(filepath, format='png', dpi=300)
            plt.show()



plot_speedup(tk, input_types)

# %%
tk.dataframe = tk.dataframe.reset_index()#.set_index(["node"])
tk.dataframe
# Out:
#      index                                               node     profile  \
# 0        0               {'name': 'main', 'type': 'function'}    71036787
# 1        1               {'name': 'main', 'type': 'function'}   295533304
# 2        2               {'name': 'main', 'type': 'function'}   430275413
# 3        3               {'name': 'main', 'type': 'function'}   566693142
# 4        4               {'name': 'main', 'type': 'function'}   613114193
# 5        5               {'name': 'main', 'type': 'function'}   648341471
# 6        6               {'name': 'main', 'type': 'function'}   735825621
# 7        7               {'name': 'main', 'type': 'function'}   773033178
# 8        8               {'name': 'main', 'type': 'function'}   904023410
# 9        9               {'name': 'main', 'type': 'function'}   910828563
# 10      10               {'name': 'main', 'type': 'function'}   916545844
# 11      11               {'name': 'main', 'type': 'function'}  1047669656
# 12      12               {'name': 'main', 'type': 'function'}  1092669097
# 13      13               {'name': 'main', 'type': 'function'}  1199745191
# 14      14               {'name': 'main', 'type': 'function'}  1241002328
# 15      15               {'name': 'main', 'type': 'function'}  1338525356
# 16      16               {'name': 'main', 'type': 'function'}  1643985974
# 17      17               {'name': 'main', 'type': 'function'}  1751399784
# 18      18               {'name': 'main', 'type': 'function'}  1831614453
# 19      19               {'name': 'main', 'type': 'function'}  1872650737
# 20      20               {'name': 'main', 'type': 'function'}  1900560005
# 21      21               {'name': 'main', 'type': 'function'}  1990342466
# 22      22               {'name': 'main', 'type': 'function'}  1994820022
# 23      23               {'name': 'main', 'type': 'function'}  2005416547
# 24      24               {'name': 'main', 'type': 'function'}  2043840030
# 25      25               {'name': 'main', 'type': 'function'}  2153564759
# 26      26               {'name': 'main', 'type': 'function'}  2160121726
# 27      27               {'name': 'main', 'type': 'function'}  2207633519
# 28      28               {'name': 'main', 'type': 'function'}  2662583836
# 29      29               {'name': 'main', 'type': 'function'}  2801232280
# 30      30               {'name': 'main', 'type': 'function'}  3000126522
# 31      31               {'name': 'main', 'type': 'function'}  3018927165
# 32      32               {'name': 'main', 'type': 'function'}  3678870530
# 33      33               {'name': 'main', 'type': 'function'}  3790422362
# 34      34               {'name': 'main', 'type': 'function'}  4124079511
# 35      35               {'name': 'main', 'type': 'function'}  4289387337
# 36      36       {'name': 'MPI_Comm_dup', 'type': 'function'}    71036787
# 37      37       {'name': 'MPI_Comm_dup', 'type': 'function'}   295533304
# 38      38       {'name': 'MPI_Comm_dup', 'type': 'function'}   430275413
# 39      39       {'name': 'MPI_Comm_dup', 'type': 'function'}   566693142
# 40      40       {'name': 'MPI_Comm_dup', 'type': 'function'}   613114193
# 41      41       {'name': 'MPI_Comm_dup', 'type': 'function'}   648341471
# 42      42       {'name': 'MPI_Comm_dup', 'type': 'function'}   735825621
# 43      43       {'name': 'MPI_Comm_dup', 'type': 'function'}   773033178
# 44      44       {'name': 'MPI_Comm_dup', 'type': 'function'}   904023410
# 45      45       {'name': 'MPI_Comm_dup', 'type': 'function'}   910828563
# 46      46       {'name': 'MPI_Comm_dup', 'type': 'function'}   916545844
# 47      47       {'name': 'MPI_Comm_dup', 'type': 'function'}  1047669656
# 48      48       {'name': 'MPI_Comm_dup', 'type': 'function'}  1092669097
# 49      49       {'name': 'MPI_Comm_dup', 'type': 'function'}  1199745191
# 50      50       {'name': 'MPI_Comm_dup', 'type': 'function'}  1241002328
# 51      51       {'name': 'MPI_Comm_dup', 'type': 'function'}  1338525356
# 52      52       {'name': 'MPI_Comm_dup', 'type': 'function'}  1643985974
# 53      53       {'name': 'MPI_Comm_dup', 'type': 'function'}  1751399784
# 54      54       {'name': 'MPI_Comm_dup', 'type': 'function'}  1831614453
# 55      55       {'name': 'MPI_Comm_dup', 'type': 'function'}  1872650737
# 56      56       {'name': 'MPI_Comm_dup', 'type': 'function'}  1900560005
# 57      57       {'name': 'MPI_Comm_dup', 'type': 'function'}  1990342466
# 58      58       {'name': 'MPI_Comm_dup', 'type': 'function'}  1994820022
# 59      59       {'name': 'MPI_Comm_dup', 'type': 'function'}  2005416547
# 60      60       {'name': 'MPI_Comm_dup', 'type': 'function'}  2043840030
# 61      61       {'name': 'MPI_Comm_dup', 'type': 'function'}  2153564759
# 62      62       {'name': 'MPI_Comm_dup', 'type': 'function'}  2160121726
# 63      63       {'name': 'MPI_Comm_dup', 'type': 'function'}  2207633519
# 64      64       {'name': 'MPI_Comm_dup', 'type': 'function'}  2662583836
# 65      65       {'name': 'MPI_Comm_dup', 'type': 'function'}  2801232280
# 66      66       {'name': 'MPI_Comm_dup', 'type': 'function'}  3000126522
# 67      67       {'name': 'MPI_Comm_dup', 'type': 'function'}  3018927165
# 68      68       {'name': 'MPI_Comm_dup', 'type': 'function'}  3678870530
# 69      69       {'name': 'MPI_Comm_dup', 'type': 'function'}  3790422362
# 70      70       {'name': 'MPI_Comm_dup', 'type': 'function'}  4124079511
# 71      71       {'name': 'MPI_Comm_dup', 'type': 'function'}  4289387337
# 72      72     {'name': 'MPI_Comm_split', 'type': 'function'}    71036787
# 73      73     {'name': 'MPI_Comm_split', 'type': 'function'}   295533304
# 74      74     {'name': 'MPI_Comm_split', 'type': 'function'}   430275413
# 75      75     {'name': 'MPI_Comm_split', 'type': 'function'}   566693142
# 76      76     {'name': 'MPI_Comm_split', 'type': 'function'}   613114193
# 77      77     {'name': 'MPI_Comm_split', 'type': 'function'}   648341471
# 78      78     {'name': 'MPI_Comm_split', 'type': 'function'}   735825621
# 79      79     {'name': 'MPI_Comm_split', 'type': 'function'}   773033178
# 80      80     {'name': 'MPI_Comm_split', 'type': 'function'}   904023410
# 81      81     {'name': 'MPI_Comm_split', 'type': 'function'}   910828563
# 82      82     {'name': 'MPI_Comm_split', 'type': 'function'}   916545844
# 83      83     {'name': 'MPI_Comm_split', 'type': 'function'}  1047669656
# 84      84     {'name': 'MPI_Comm_split', 'type': 'function'}  1092669097
# 85      85     {'name': 'MPI_Comm_split', 'type': 'function'}  1199745191
# 86      86     {'name': 'MPI_Comm_split', 'type': 'function'}  1241002328
# 87      87     {'name': 'MPI_Comm_split', 'type': 'function'}  1338525356
# 88      88     {'name': 'MPI_Comm_split', 'type': 'function'}  1643985974
# 89      89     {'name': 'MPI_Comm_split', 'type': 'function'}  1751399784
# 90      90     {'name': 'MPI_Comm_split', 'type': 'function'}  1831614453
# 91      91     {'name': 'MPI_Comm_split', 'type': 'function'}  1872650737
# 92      92     {'name': 'MPI_Comm_split', 'type': 'function'}  1900560005
# 93      93     {'name': 'MPI_Comm_split', 'type': 'function'}  1990342466
# 94      94     {'name': 'MPI_Comm_split', 'type': 'function'}  1994820022
# 95      95     {'name': 'MPI_Comm_split', 'type': 'function'}  2005416547
# 96      96     {'name': 'MPI_Comm_split', 'type': 'function'}  2043840030
# 97      97     {'name': 'MPI_Comm_split', 'type': 'function'}  2153564759
# 98      98     {'name': 'MPI_Comm_split', 'type': 'function'}  2160121726
# 99      99     {'name': 'MPI_Comm_split', 'type': 'function'}  2207633519
# 100    100     {'name': 'MPI_Comm_split', 'type': 'function'}  2662583836
# 101    101     {'name': 'MPI_Comm_split', 'type': 'function'}  2801232280
# 102    102     {'name': 'MPI_Comm_split', 'type': 'function'}  3000126522
# 103    103     {'name': 'MPI_Comm_split', 'type': 'function'}  3018927165
# 104    104     {'name': 'MPI_Comm_split', 'type': 'function'}  3678870530
# 105    105     {'name': 'MPI_Comm_split', 'type': 'function'}  3790422362
# 106    106     {'name': 'MPI_Comm_split', 'type': 'function'}  4124079511
# 107    107     {'name': 'MPI_Comm_split', 'type': 'function'}  4289387337
# 108    108       {'name': 'MPI_Finalize', 'type': 'function'}    71036787
# 109    109       {'name': 'MPI_Finalize', 'type': 'function'}   295533304
# 110    110       {'name': 'MPI_Finalize', 'type': 'function'}   430275413
# 111    111       {'name': 'MPI_Finalize', 'type': 'function'}   566693142
# 112    112       {'name': 'MPI_Finalize', 'type': 'function'}   613114193
# 113    113       {'name': 'MPI_Finalize', 'type': 'function'}   648341471
# 114    114       {'name': 'MPI_Finalize', 'type': 'function'}   735825621
# 115    115       {'name': 'MPI_Finalize', 'type': 'function'}   773033178
# 116    116       {'name': 'MPI_Finalize', 'type': 'function'}   904023410
# 117    117       {'name': 'MPI_Finalize', 'type': 'function'}   910828563
# 118    118       {'name': 'MPI_Finalize', 'type': 'function'}   916545844
# 119    119       {'name': 'MPI_Finalize', 'type': 'function'}  1047669656
# 120    120       {'name': 'MPI_Finalize', 'type': 'function'}  1092669097
# 121    121       {'name': 'MPI_Finalize', 'type': 'function'}  1199745191
# 122    122       {'name': 'MPI_Finalize', 'type': 'function'}  1241002328
# 123    123       {'name': 'MPI_Finalize', 'type': 'function'}  1338525356
# 124    124       {'name': 'MPI_Finalize', 'type': 'function'}  1643985974
# 125    125       {'name': 'MPI_Finalize', 'type': 'function'}  1751399784
# 126    126       {'name': 'MPI_Finalize', 'type': 'function'}  1831614453
# 127    127       {'name': 'MPI_Finalize', 'type': 'function'}  1872650737
# 128    128       {'name': 'MPI_Finalize', 'type': 'function'}  1900560005
# 129    129       {'name': 'MPI_Finalize', 'type': 'function'}  1990342466
# 130    130       {'name': 'MPI_Finalize', 'type': 'function'}  1994820022
# 131    131       {'name': 'MPI_Finalize', 'type': 'function'}  2005416547
# 132    132       {'name': 'MPI_Finalize', 'type': 'function'}  2043840030
# 133    133       {'name': 'MPI_Finalize', 'type': 'function'}  2153564759
# 134    134       {'name': 'MPI_Finalize', 'type': 'function'}  2160121726
# 135    135       {'name': 'MPI_Finalize', 'type': 'function'}  2207633519
# 136    136       {'name': 'MPI_Finalize', 'type': 'function'}  2662583836
# 137    137       {'name': 'MPI_Finalize', 'type': 'function'}  2801232280
# 138    138       {'name': 'MPI_Finalize', 'type': 'function'}  3000126522
# 139    139       {'name': 'MPI_Finalize', 'type': 'function'}  3018927165
# 140    140       {'name': 'MPI_Finalize', 'type': 'function'}  3678870530
# 141    141       {'name': 'MPI_Finalize', 'type': 'function'}  3790422362
# 142    142       {'name': 'MPI_Finalize', 'type': 'function'}  4124079511
# 143    143       {'name': 'MPI_Finalize', 'type': 'function'}  4289387337
# 144    144      {'name': 'MPI_Finalized', 'type': 'function'}    71036787
# 145    145      {'name': 'MPI_Finalized', 'type': 'function'}   295533304
# 146    146      {'name': 'MPI_Finalized', 'type': 'function'}   430275413
# 147    147      {'name': 'MPI_Finalized', 'type': 'function'}   566693142
# 148    148      {'name': 'MPI_Finalized', 'type': 'function'}   613114193
# 149    149      {'name': 'MPI_Finalized', 'type': 'function'}   648341471
# 150    150      {'name': 'MPI_Finalized', 'type': 'function'}   735825621
# 151    151      {'name': 'MPI_Finalized', 'type': 'function'}   773033178
# 152    152      {'name': 'MPI_Finalized', 'type': 'function'}   904023410
# 153    153      {'name': 'MPI_Finalized', 'type': 'function'}   910828563
# 154    154      {'name': 'MPI_Finalized', 'type': 'function'}   916545844
# 155    155      {'name': 'MPI_Finalized', 'type': 'function'}  1047669656
# 156    156      {'name': 'MPI_Finalized', 'type': 'function'}  1092669097
# 157    157      {'name': 'MPI_Finalized', 'type': 'function'}  1199745191
# 158    158      {'name': 'MPI_Finalized', 'type': 'function'}  1241002328
# 159    159      {'name': 'MPI_Finalized', 'type': 'function'}  1338525356
# 160    160      {'name': 'MPI_Finalized', 'type': 'function'}  1643985974
# 161    161      {'name': 'MPI_Finalized', 'type': 'function'}  1751399784
# 162    162      {'name': 'MPI_Finalized', 'type': 'function'}  1831614453
# 163    163      {'name': 'MPI_Finalized', 'type': 'function'}  1872650737
# 164    164      {'name': 'MPI_Finalized', 'type': 'function'}  1900560005
# 165    165      {'name': 'MPI_Finalized', 'type': 'function'}  1990342466
# 166    166      {'name': 'MPI_Finalized', 'type': 'function'}  1994820022
# 167    167      {'name': 'MPI_Finalized', 'type': 'function'}  2005416547
# 168    168      {'name': 'MPI_Finalized', 'type': 'function'}  2043840030
# 169    169      {'name': 'MPI_Finalized', 'type': 'function'}  2153564759
# 170    170      {'name': 'MPI_Finalized', 'type': 'function'}  2160121726
# 171    171      {'name': 'MPI_Finalized', 'type': 'function'}  2207633519
# 172    172      {'name': 'MPI_Finalized', 'type': 'function'}  2662583836
# 173    173      {'name': 'MPI_Finalized', 'type': 'function'}  2801232280
# 174    174      {'name': 'MPI_Finalized', 'type': 'function'}  3000126522
# 175    175      {'name': 'MPI_Finalized', 'type': 'function'}  3018927165
# 176    176      {'name': 'MPI_Finalized', 'type': 'function'}  3678870530
# 177    177      {'name': 'MPI_Finalized', 'type': 'function'}  3790422362
# 178    178      {'name': 'MPI_Finalized', 'type': 'function'}  4124079511
# 179    179      {'name': 'MPI_Finalized', 'type': 'function'}  4289387337
# 180    180           {'name': 'MPI_Init', 'type': 'function'}    71036787
# 181    181           {'name': 'MPI_Init', 'type': 'function'}   295533304
# 182    182           {'name': 'MPI_Init', 'type': 'function'}   430275413
# 183    183           {'name': 'MPI_Init', 'type': 'function'}   566693142
# 184    184           {'name': 'MPI_Init', 'type': 'function'}   613114193
# 185    185           {'name': 'MPI_Init', 'type': 'function'}   648341471
# 186    186           {'name': 'MPI_Init', 'type': 'function'}   735825621
# 187    187           {'name': 'MPI_Init', 'type': 'function'}   773033178
# 188    188           {'name': 'MPI_Init', 'type': 'function'}   904023410
# 189    189           {'name': 'MPI_Init', 'type': 'function'}   910828563
# 190    190           {'name': 'MPI_Init', 'type': 'function'}   916545844
# 191    191           {'name': 'MPI_Init', 'type': 'function'}  1047669656
# 192    192           {'name': 'MPI_Init', 'type': 'function'}  1092669097
# 193    193           {'name': 'MPI_Init', 'type': 'function'}  1199745191
# 194    194           {'name': 'MPI_Init', 'type': 'function'}  1241002328
# 195    195           {'name': 'MPI_Init', 'type': 'function'}  1338525356
# 196    196           {'name': 'MPI_Init', 'type': 'function'}  1643985974
# 197    197           {'name': 'MPI_Init', 'type': 'function'}  1751399784
# 198    198           {'name': 'MPI_Init', 'type': 'function'}  1831614453
# 199    199           {'name': 'MPI_Init', 'type': 'function'}  1872650737
# 200    200           {'name': 'MPI_Init', 'type': 'function'}  1900560005
# 201    201           {'name': 'MPI_Init', 'type': 'function'}  1990342466
# 202    202           {'name': 'MPI_Init', 'type': 'function'}  1994820022
# 203    203           {'name': 'MPI_Init', 'type': 'function'}  2005416547
# 204    204           {'name': 'MPI_Init', 'type': 'function'}  2043840030
# 205    205           {'name': 'MPI_Init', 'type': 'function'}  2153564759
# 206    206           {'name': 'MPI_Init', 'type': 'function'}  2160121726
# 207    207           {'name': 'MPI_Init', 'type': 'function'}  2207633519
# 208    208           {'name': 'MPI_Init', 'type': 'function'}  2662583836
# 209    209           {'name': 'MPI_Init', 'type': 'function'}  2801232280
# 210    210           {'name': 'MPI_Init', 'type': 'function'}  3000126522
# 211    211           {'name': 'MPI_Init', 'type': 'function'}  3018927165
# 212    212           {'name': 'MPI_Init', 'type': 'function'}  3678870530
# 213    213           {'name': 'MPI_Init', 'type': 'function'}  3790422362
# 214    214           {'name': 'MPI_Init', 'type': 'function'}  4124079511
# 215    215           {'name': 'MPI_Init', 'type': 'function'}  4289387337
# 216    216    {'name': 'MPI_Initialized', 'type': 'function'}    71036787
# 217    217    {'name': 'MPI_Initialized', 'type': 'function'}   295533304
# 218    218    {'name': 'MPI_Initialized', 'type': 'function'}   430275413
# 219    219    {'name': 'MPI_Initialized', 'type': 'function'}   566693142
# 220    220    {'name': 'MPI_Initialized', 'type': 'function'}   613114193
# 221    221    {'name': 'MPI_Initialized', 'type': 'function'}   648341471
# 222    222    {'name': 'MPI_Initialized', 'type': 'function'}   735825621
# 223    223    {'name': 'MPI_Initialized', 'type': 'function'}   773033178
# 224    224    {'name': 'MPI_Initialized', 'type': 'function'}   904023410
# 225    225    {'name': 'MPI_Initialized', 'type': 'function'}   910828563
# 226    226    {'name': 'MPI_Initialized', 'type': 'function'}   916545844
# 227    227    {'name': 'MPI_Initialized', 'type': 'function'}  1047669656
# 228    228    {'name': 'MPI_Initialized', 'type': 'function'}  1092669097
# 229    229    {'name': 'MPI_Initialized', 'type': 'function'}  1199745191
# 230    230    {'name': 'MPI_Initialized', 'type': 'function'}  1241002328
# 231    231    {'name': 'MPI_Initialized', 'type': 'function'}  1338525356
# 232    232    {'name': 'MPI_Initialized', 'type': 'function'}  1643985974
# 233    233    {'name': 'MPI_Initialized', 'type': 'function'}  1751399784
# 234    234    {'name': 'MPI_Initialized', 'type': 'function'}  1831614453
# 235    235    {'name': 'MPI_Initialized', 'type': 'function'}  1872650737
# 236    236    {'name': 'MPI_Initialized', 'type': 'function'}  1900560005
# 237    237    {'name': 'MPI_Initialized', 'type': 'function'}  1990342466
# 238    238    {'name': 'MPI_Initialized', 'type': 'function'}  1994820022
# 239    239    {'name': 'MPI_Initialized', 'type': 'function'}  2005416547
# 240    240    {'name': 'MPI_Initialized', 'type': 'function'}  2043840030
# 241    241    {'name': 'MPI_Initialized', 'type': 'function'}  2153564759
# 242    242    {'name': 'MPI_Initialized', 'type': 'function'}  2160121726
# 243    243    {'name': 'MPI_Initialized', 'type': 'function'}  2207633519
# 244    244    {'name': 'MPI_Initialized', 'type': 'function'}  2662583836
# 245    245    {'name': 'MPI_Initialized', 'type': 'function'}  2801232280
# 246    246    {'name': 'MPI_Initialized', 'type': 'function'}  3000126522
# 247    247    {'name': 'MPI_Initialized', 'type': 'function'}  3018927165
# 248    248    {'name': 'MPI_Initialized', 'type': 'function'}  3678870530
# 249    249    {'name': 'MPI_Initialized', 'type': 'function'}  3790422362
# 250    250    {'name': 'MPI_Initialized', 'type': 'function'}  4124079511
# 251    251    {'name': 'MPI_Initialized', 'type': 'function'}  4289387337
# 252    252               {'name': 'comm', 'type': 'function'}    71036787
# 253    253               {'name': 'comm', 'type': 'function'}   295533304
# 254    254               {'name': 'comm', 'type': 'function'}   430275413
# 255    255               {'name': 'comm', 'type': 'function'}   566693142
# 256    256               {'name': 'comm', 'type': 'function'}   613114193
# 257    257               {'name': 'comm', 'type': 'function'}   648341471
# 258    258               {'name': 'comm', 'type': 'function'}   735825621
# 259    259               {'name': 'comm', 'type': 'function'}   773033178
# 260    260               {'name': 'comm', 'type': 'function'}   904023410
# 261    261               {'name': 'comm', 'type': 'function'}   910828563
# 262    262               {'name': 'comm', 'type': 'function'}   916545844
# 263    263               {'name': 'comm', 'type': 'function'}  1047669656
# 264    264               {'name': 'comm', 'type': 'function'}  1092669097
# 265    265               {'name': 'comm', 'type': 'function'}  1199745191
# 266    266               {'name': 'comm', 'type': 'function'}  1241002328
# 267    267               {'name': 'comm', 'type': 'function'}  1338525356
# 268    268               {'name': 'comm', 'type': 'function'}  1643985974
# 269    269               {'name': 'comm', 'type': 'function'}  1751399784
# 270    270               {'name': 'comm', 'type': 'function'}  1831614453
# 271    271               {'name': 'comm', 'type': 'function'}  1872650737
# 272    272               {'name': 'comm', 'type': 'function'}  1900560005
# 273    273               {'name': 'comm', 'type': 'function'}  1990342466
# 274    274               {'name': 'comm', 'type': 'function'}  1994820022
# 275    275               {'name': 'comm', 'type': 'function'}  2005416547
# 276    276               {'name': 'comm', 'type': 'function'}  2043840030
# 277    277               {'name': 'comm', 'type': 'function'}  2153564759
# 278    278               {'name': 'comm', 'type': 'function'}  2160121726
# 279    279               {'name': 'comm', 'type': 'function'}  2207633519
# 280    280               {'name': 'comm', 'type': 'function'}  2662583836
# 281    281               {'name': 'comm', 'type': 'function'}  2801232280
# 282    282               {'name': 'comm', 'type': 'function'}  3000126522
# 283    283               {'name': 'comm', 'type': 'function'}  3018927165
# 284    284               {'name': 'comm', 'type': 'function'}  3678870530
# 285    285               {'name': 'comm', 'type': 'function'}  3790422362
# 286    286               {'name': 'comm', 'type': 'function'}  4124079511
# 287    287               {'name': 'comm', 'type': 'function'}  4289387337
# 288    288         {'name': 'comm_large', 'type': 'function'}    71036787
# 289    289         {'name': 'comm_large', 'type': 'function'}   295533304
# 290    290         {'name': 'comm_large', 'type': 'function'}   430275413
# 291    291         {'name': 'comm_large', 'type': 'function'}   566693142
# 292    292         {'name': 'comm_large', 'type': 'function'}   613114193
# 293    293         {'name': 'comm_large', 'type': 'function'}   648341471
# 294    294         {'name': 'comm_large', 'type': 'function'}   735825621
# 295    295         {'name': 'comm_large', 'type': 'function'}   773033178
# 296    296         {'name': 'comm_large', 'type': 'function'}   904023410
# 297    297         {'name': 'comm_large', 'type': 'function'}   910828563
# 298    298         {'name': 'comm_large', 'type': 'function'}   916545844
# 299    299         {'name': 'comm_large', 'type': 'function'}  1047669656
# 300    300         {'name': 'comm_large', 'type': 'function'}  1092669097
# 301    301         {'name': 'comm_large', 'type': 'function'}  1199745191
# 302    302         {'name': 'comm_large', 'type': 'function'}  1241002328
# 303    303         {'name': 'comm_large', 'type': 'function'}  1338525356
# 304    304         {'name': 'comm_large', 'type': 'function'}  1643985974
# 305    305         {'name': 'comm_large', 'type': 'function'}  1751399784
# 306    306         {'name': 'comm_large', 'type': 'function'}  1831614453
# 307    307         {'name': 'comm_large', 'type': 'function'}  1872650737
# 308    308         {'name': 'comm_large', 'type': 'function'}  1900560005
# 309    309         {'name': 'comm_large', 'type': 'function'}  1990342466
# 310    310         {'name': 'comm_large', 'type': 'function'}  1994820022
# 311    311         {'name': 'comm_large', 'type': 'function'}  2005416547
# 312    312         {'name': 'comm_large', 'type': 'function'}  2043840030
# 313    313         {'name': 'comm_large', 'type': 'function'}  2153564759
# 314    314         {'name': 'comm_large', 'type': 'function'}  2160121726
# 315    315         {'name': 'comm_large', 'type': 'function'}  2207633519
# 316    316         {'name': 'comm_large', 'type': 'function'}  2662583836
# 317    317         {'name': 'comm_large', 'type': 'function'}  2801232280
# 318    318         {'name': 'comm_large', 'type': 'function'}  3000126522
# 319    319         {'name': 'comm_large', 'type': 'function'}  3018927165
# 320    320         {'name': 'comm_large', 'type': 'function'}  3678870530
# 321    321         {'name': 'comm_large', 'type': 'function'}  3790422362
# 322    322         {'name': 'comm_large', 'type': 'function'}  4124079511
# 323    323         {'name': 'comm_large', 'type': 'function'}  4289387337
# 324    324       {'name': 'MPI_Alltoall', 'type': 'function'}    71036787
# 325    325       {'name': 'MPI_Alltoall', 'type': 'function'}   295533304
# 326    326       {'name': 'MPI_Alltoall', 'type': 'function'}   430275413
# 327    327       {'name': 'MPI_Alltoall', 'type': 'function'}   566693142
# 328    328       {'name': 'MPI_Alltoall', 'type': 'function'}   613114193
# 329    329       {'name': 'MPI_Alltoall', 'type': 'function'}   648341471
# 330    330       {'name': 'MPI_Alltoall', 'type': 'function'}   735825621
# 331    331       {'name': 'MPI_Alltoall', 'type': 'function'}   773033178
# 332    332       {'name': 'MPI_Alltoall', 'type': 'function'}   904023410
# 333    333       {'name': 'MPI_Alltoall', 'type': 'function'}   910828563
# 334    334       {'name': 'MPI_Alltoall', 'type': 'function'}   916545844
# 335    335       {'name': 'MPI_Alltoall', 'type': 'function'}  1047669656
# 336    336       {'name': 'MPI_Alltoall', 'type': 'function'}  1092669097
# 337    337       {'name': 'MPI_Alltoall', 'type': 'function'}  1199745191
# 338    338       {'name': 'MPI_Alltoall', 'type': 'function'}  1241002328
# 339    339       {'name': 'MPI_Alltoall', 'type': 'function'}  1338525356
# 340    340       {'name': 'MPI_Alltoall', 'type': 'function'}  1643985974
# 341    341       {'name': 'MPI_Alltoall', 'type': 'function'}  1751399784
# 342    342       {'name': 'MPI_Alltoall', 'type': 'function'}  1831614453
# 343    343       {'name': 'MPI_Alltoall', 'type': 'function'}  1872650737
# 344    344       {'name': 'MPI_Alltoall', 'type': 'function'}  1900560005
# 345    345       {'name': 'MPI_Alltoall', 'type': 'function'}  1990342466
# 346    346       {'name': 'MPI_Alltoall', 'type': 'function'}  1994820022
# 347    347       {'name': 'MPI_Alltoall', 'type': 'function'}  2005416547
# 348    348       {'name': 'MPI_Alltoall', 'type': 'function'}  2043840030
# 349    349       {'name': 'MPI_Alltoall', 'type': 'function'}  2153564759
# 350    350       {'name': 'MPI_Alltoall', 'type': 'function'}  2160121726
# 351    351       {'name': 'MPI_Alltoall', 'type': 'function'}  2207633519
# 352    352       {'name': 'MPI_Alltoall', 'type': 'function'}  2662583836
# 353    353       {'name': 'MPI_Alltoall', 'type': 'function'}  2801232280
# 354    354       {'name': 'MPI_Alltoall', 'type': 'function'}  3000126522
# 355    355       {'name': 'MPI_Alltoall', 'type': 'function'}  3018927165
# 356    356       {'name': 'MPI_Alltoall', 'type': 'function'}  3678870530
# 357    357       {'name': 'MPI_Alltoall', 'type': 'function'}  3790422362
# 358    358       {'name': 'MPI_Alltoall', 'type': 'function'}  4124079511
# 359    359       {'name': 'MPI_Alltoall', 'type': 'function'}  4289387337
# 360    360      {'name': 'MPI_Alltoallv', 'type': 'function'}    71036787
# 361    361      {'name': 'MPI_Alltoallv', 'type': 'function'}   295533304
# 362    362      {'name': 'MPI_Alltoallv', 'type': 'function'}   430275413
# 363    363      {'name': 'MPI_Alltoallv', 'type': 'function'}   566693142
# 364    364      {'name': 'MPI_Alltoallv', 'type': 'function'}   613114193
# 365    365      {'name': 'MPI_Alltoallv', 'type': 'function'}   648341471
# 366    366      {'name': 'MPI_Alltoallv', 'type': 'function'}   735825621
# 367    367      {'name': 'MPI_Alltoallv', 'type': 'function'}   773033178
# 368    368      {'name': 'MPI_Alltoallv', 'type': 'function'}   904023410
# 369    369      {'name': 'MPI_Alltoallv', 'type': 'function'}   910828563
# 370    370      {'name': 'MPI_Alltoallv', 'type': 'function'}   916545844
# 371    371      {'name': 'MPI_Alltoallv', 'type': 'function'}  1047669656
# 372    372      {'name': 'MPI_Alltoallv', 'type': 'function'}  1092669097
# 373    373      {'name': 'MPI_Alltoallv', 'type': 'function'}  1199745191
# 374    374      {'name': 'MPI_Alltoallv', 'type': 'function'}  1241002328
# 375    375      {'name': 'MPI_Alltoallv', 'type': 'function'}  1338525356
# 376    376      {'name': 'MPI_Alltoallv', 'type': 'function'}  1643985974
# 377    377      {'name': 'MPI_Alltoallv', 'type': 'function'}  1751399784
# 378    378      {'name': 'MPI_Alltoallv', 'type': 'function'}  1831614453
# 379    379      {'name': 'MPI_Alltoallv', 'type': 'function'}  1872650737
# 380    380      {'name': 'MPI_Alltoallv', 'type': 'function'}  1900560005
# 381    381      {'name': 'MPI_Alltoallv', 'type': 'function'}  1990342466
# 382    382      {'name': 'MPI_Alltoallv', 'type': 'function'}  1994820022
# 383    383      {'name': 'MPI_Alltoallv', 'type': 'function'}  2005416547
# 384    384      {'name': 'MPI_Alltoallv', 'type': 'function'}  2043840030
# 385    385      {'name': 'MPI_Alltoallv', 'type': 'function'}  2153564759
# 386    386      {'name': 'MPI_Alltoallv', 'type': 'function'}  2160121726
# 387    387      {'name': 'MPI_Alltoallv', 'type': 'function'}  2207633519
# 388    388      {'name': 'MPI_Alltoallv', 'type': 'function'}  2662583836
# 389    389      {'name': 'MPI_Alltoallv', 'type': 'function'}  2801232280
# 390    390      {'name': 'MPI_Alltoallv', 'type': 'function'}  3000126522
# 391    391      {'name': 'MPI_Alltoallv', 'type': 'function'}  3018927165
# 392    392      {'name': 'MPI_Alltoallv', 'type': 'function'}  3678870530
# 393    393      {'name': 'MPI_Alltoallv', 'type': 'function'}  3790422362
# 394    394      {'name': 'MPI_Alltoallv', 'type': 'function'}  4124079511
# 395    395      {'name': 'MPI_Alltoallv', 'type': 'function'}  4289387337
# 396    396         {'name': 'MPI_Gather', 'type': 'function'}    71036787
# 397    397         {'name': 'MPI_Gather', 'type': 'function'}   295533304
# 398    398         {'name': 'MPI_Gather', 'type': 'function'}   430275413
# 399    399         {'name': 'MPI_Gather', 'type': 'function'}   566693142
# 400    400         {'name': 'MPI_Gather', 'type': 'function'}   613114193
# 401    401         {'name': 'MPI_Gather', 'type': 'function'}   648341471
# 402    402         {'name': 'MPI_Gather', 'type': 'function'}   735825621
# 403    403         {'name': 'MPI_Gather', 'type': 'function'}   773033178
# 404    404         {'name': 'MPI_Gather', 'type': 'function'}   904023410
# 405    405         {'name': 'MPI_Gather', 'type': 'function'}   910828563
# 406    406         {'name': 'MPI_Gather', 'type': 'function'}   916545844
# 407    407         {'name': 'MPI_Gather', 'type': 'function'}  1047669656
# 408    408         {'name': 'MPI_Gather', 'type': 'function'}  1092669097
# 409    409         {'name': 'MPI_Gather', 'type': 'function'}  1199745191
# 410    410         {'name': 'MPI_Gather', 'type': 'function'}  1241002328
# 411    411         {'name': 'MPI_Gather', 'type': 'function'}  1338525356
# 412    412         {'name': 'MPI_Gather', 'type': 'function'}  1643985974
# 413    413         {'name': 'MPI_Gather', 'type': 'function'}  1751399784
# 414    414         {'name': 'MPI_Gather', 'type': 'function'}  1831614453
# 415    415         {'name': 'MPI_Gather', 'type': 'function'}  1872650737
# 416    416         {'name': 'MPI_Gather', 'type': 'function'}  1900560005
# 417    417         {'name': 'MPI_Gather', 'type': 'function'}  1990342466
# 418    418         {'name': 'MPI_Gather', 'type': 'function'}  1994820022
# 419    419         {'name': 'MPI_Gather', 'type': 'function'}  2005416547
# 420    420         {'name': 'MPI_Gather', 'type': 'function'}  2043840030
# 421    421         {'name': 'MPI_Gather', 'type': 'function'}  2153564759
# 422    422         {'name': 'MPI_Gather', 'type': 'function'}  2160121726
# 423    423         {'name': 'MPI_Gather', 'type': 'function'}  2207633519
# 424    424         {'name': 'MPI_Gather', 'type': 'function'}  2662583836
# 425    425         {'name': 'MPI_Gather', 'type': 'function'}  2801232280
# 426    426         {'name': 'MPI_Gather', 'type': 'function'}  3000126522
# 427    427         {'name': 'MPI_Gather', 'type': 'function'}  3018927165
# 428    428         {'name': 'MPI_Gather', 'type': 'function'}  3678870530
# 429    429         {'name': 'MPI_Gather', 'type': 'function'}  3790422362
# 430    430         {'name': 'MPI_Gather', 'type': 'function'}  4124079511
# 431    431         {'name': 'MPI_Gather', 'type': 'function'}  4289387337
# 432    432        {'name': 'MPI_Gatherv', 'type': 'function'}    71036787
# 433    433        {'name': 'MPI_Gatherv', 'type': 'function'}   295533304
# 434    434        {'name': 'MPI_Gatherv', 'type': 'function'}   430275413
# 435    435        {'name': 'MPI_Gatherv', 'type': 'function'}   566693142
# 436    436        {'name': 'MPI_Gatherv', 'type': 'function'}   613114193
# 437    437        {'name': 'MPI_Gatherv', 'type': 'function'}   648341471
# 438    438        {'name': 'MPI_Gatherv', 'type': 'function'}   735825621
# 439    439        {'name': 'MPI_Gatherv', 'type': 'function'}   773033178
# 440    440        {'name': 'MPI_Gatherv', 'type': 'function'}   904023410
# 441    441        {'name': 'MPI_Gatherv', 'type': 'function'}   910828563
# 442    442        {'name': 'MPI_Gatherv', 'type': 'function'}   916545844
# 443    443        {'name': 'MPI_Gatherv', 'type': 'function'}  1047669656
# 444    444        {'name': 'MPI_Gatherv', 'type': 'function'}  1092669097
# 445    445        {'name': 'MPI_Gatherv', 'type': 'function'}  1199745191
# 446    446        {'name': 'MPI_Gatherv', 'type': 'function'}  1241002328
# 447    447        {'name': 'MPI_Gatherv', 'type': 'function'}  1338525356
# 448    448        {'name': 'MPI_Gatherv', 'type': 'function'}  1643985974
# 449    449        {'name': 'MPI_Gatherv', 'type': 'function'}  1751399784
# 450    450        {'name': 'MPI_Gatherv', 'type': 'function'}  1831614453
# 451    451        {'name': 'MPI_Gatherv', 'type': 'function'}  1872650737
# 452    452        {'name': 'MPI_Gatherv', 'type': 'function'}  1900560005
# 453    453        {'name': 'MPI_Gatherv', 'type': 'function'}  1990342466
# 454    454        {'name': 'MPI_Gatherv', 'type': 'function'}  1994820022
# 455    455        {'name': 'MPI_Gatherv', 'type': 'function'}  2005416547
# 456    456        {'name': 'MPI_Gatherv', 'type': 'function'}  2043840030
# 457    457        {'name': 'MPI_Gatherv', 'type': 'function'}  2153564759
# 458    458        {'name': 'MPI_Gatherv', 'type': 'function'}  2160121726
# 459    459        {'name': 'MPI_Gatherv', 'type': 'function'}  2207633519
# 460    460        {'name': 'MPI_Gatherv', 'type': 'function'}  2662583836
# 461    461        {'name': 'MPI_Gatherv', 'type': 'function'}  2801232280
# 462    462        {'name': 'MPI_Gatherv', 'type': 'function'}  3000126522
# 463    463        {'name': 'MPI_Gatherv', 'type': 'function'}  3018927165
# 464    464        {'name': 'MPI_Gatherv', 'type': 'function'}  3678870530
# 465    465        {'name': 'MPI_Gatherv', 'type': 'function'}  3790422362
# 466    466        {'name': 'MPI_Gatherv', 'type': 'function'}  4124079511
# 467    467        {'name': 'MPI_Gatherv', 'type': 'function'}  4289387337
# 468    468        {'name': 'MPI_Scatter', 'type': 'function'}    71036787
# 469    469        {'name': 'MPI_Scatter', 'type': 'function'}   295533304
# 470    470        {'name': 'MPI_Scatter', 'type': 'function'}   430275413
# 471    471        {'name': 'MPI_Scatter', 'type': 'function'}   566693142
# 472    472        {'name': 'MPI_Scatter', 'type': 'function'}   613114193
# 473    473        {'name': 'MPI_Scatter', 'type': 'function'}   648341471
# 474    474        {'name': 'MPI_Scatter', 'type': 'function'}   735825621
# 475    475        {'name': 'MPI_Scatter', 'type': 'function'}   773033178
# 476    476        {'name': 'MPI_Scatter', 'type': 'function'}   904023410
# 477    477        {'name': 'MPI_Scatter', 'type': 'function'}   910828563
# 478    478        {'name': 'MPI_Scatter', 'type': 'function'}   916545844
# 479    479        {'name': 'MPI_Scatter', 'type': 'function'}  1047669656
# 480    480        {'name': 'MPI_Scatter', 'type': 'function'}  1092669097
# 481    481        {'name': 'MPI_Scatter', 'type': 'function'}  1199745191
# 482    482        {'name': 'MPI_Scatter', 'type': 'function'}  1241002328
# 483    483        {'name': 'MPI_Scatter', 'type': 'function'}  1338525356
# 484    484        {'name': 'MPI_Scatter', 'type': 'function'}  1643985974
# 485    485        {'name': 'MPI_Scatter', 'type': 'function'}  1751399784
# 486    486        {'name': 'MPI_Scatter', 'type': 'function'}  1831614453
# 487    487        {'name': 'MPI_Scatter', 'type': 'function'}  1872650737
# 488    488        {'name': 'MPI_Scatter', 'type': 'function'}  1900560005
# 489    489        {'name': 'MPI_Scatter', 'type': 'function'}  1990342466
# 490    490        {'name': 'MPI_Scatter', 'type': 'function'}  1994820022
# 491    491        {'name': 'MPI_Scatter', 'type': 'function'}  2005416547
# 492    492        {'name': 'MPI_Scatter', 'type': 'function'}  2043840030
# 493    493        {'name': 'MPI_Scatter', 'type': 'function'}  2153564759
# 494    494        {'name': 'MPI_Scatter', 'type': 'function'}  2160121726
# 495    495        {'name': 'MPI_Scatter', 'type': 'function'}  2207633519
# 496    496        {'name': 'MPI_Scatter', 'type': 'function'}  2662583836
# 497    497        {'name': 'MPI_Scatter', 'type': 'function'}  2801232280
# 498    498        {'name': 'MPI_Scatter', 'type': 'function'}  3000126522
# 499    499        {'name': 'MPI_Scatter', 'type': 'function'}  3018927165
# 500    500        {'name': 'MPI_Scatter', 'type': 'function'}  3678870530
# 501    501        {'name': 'MPI_Scatter', 'type': 'function'}  3790422362
# 502    502        {'name': 'MPI_Scatter', 'type': 'function'}  4124079511
# 503    503        {'name': 'MPI_Scatter', 'type': 'function'}  4289387337
# 504    504         {'name': 'comm_small', 'type': 'function'}    71036787
# 505    505         {'name': 'comm_small', 'type': 'function'}   295533304
# 506    506         {'name': 'comm_small', 'type': 'function'}   430275413
# 507    507         {'name': 'comm_small', 'type': 'function'}   566693142
# 508    508         {'name': 'comm_small', 'type': 'function'}   613114193
# 509    509         {'name': 'comm_small', 'type': 'function'}   648341471
# 510    510         {'name': 'comm_small', 'type': 'function'}   735825621
# 511    511         {'name': 'comm_small', 'type': 'function'}   773033178
# 512    512         {'name': 'comm_small', 'type': 'function'}   904023410
# 513    513         {'name': 'comm_small', 'type': 'function'}   910828563
# 514    514         {'name': 'comm_small', 'type': 'function'}   916545844
# 515    515         {'name': 'comm_small', 'type': 'function'}  1047669656
# 516    516         {'name': 'comm_small', 'type': 'function'}  1092669097
# 517    517         {'name': 'comm_small', 'type': 'function'}  1199745191
# 518    518         {'name': 'comm_small', 'type': 'function'}  1241002328
# 519    519         {'name': 'comm_small', 'type': 'function'}  1338525356
# 520    520         {'name': 'comm_small', 'type': 'function'}  1643985974
# 521    521         {'name': 'comm_small', 'type': 'function'}  1751399784
# 522    522         {'name': 'comm_small', 'type': 'function'}  1831614453
# 523    523         {'name': 'comm_small', 'type': 'function'}  1872650737
# 524    524         {'name': 'comm_small', 'type': 'function'}  1900560005
# 525    525         {'name': 'comm_small', 'type': 'function'}  1990342466
# 526    526         {'name': 'comm_small', 'type': 'function'}  1994820022
# 527    527         {'name': 'comm_small', 'type': 'function'}  2005416547
# 528    528         {'name': 'comm_small', 'type': 'function'}  2043840030
# 529    529         {'name': 'comm_small', 'type': 'function'}  2153564759
# 530    530         {'name': 'comm_small', 'type': 'function'}  2160121726
# 531    531         {'name': 'comm_small', 'type': 'function'}  2207633519
# 532    532         {'name': 'comm_small', 'type': 'function'}  2662583836
# 533    533         {'name': 'comm_small', 'type': 'function'}  2801232280
# 534    534         {'name': 'comm_small', 'type': 'function'}  3000126522
# 535    535         {'name': 'comm_small', 'type': 'function'}  3018927165
# 536    536         {'name': 'comm_small', 'type': 'function'}  3678870530
# 537    537         {'name': 'comm_small', 'type': 'function'}  3790422362
# 538    538         {'name': 'comm_small', 'type': 'function'}  4124079511
# 539    539         {'name': 'comm_small', 'type': 'function'}  4289387337
# 540    540          {'name': 'MPI_Bcast', 'type': 'function'}    71036787
# 541    541          {'name': 'MPI_Bcast', 'type': 'function'}   295533304
# 542    542          {'name': 'MPI_Bcast', 'type': 'function'}   430275413
# 543    543          {'name': 'MPI_Bcast', 'type': 'function'}   566693142
# 544    544          {'name': 'MPI_Bcast', 'type': 'function'}   613114193
# 545    545          {'name': 'MPI_Bcast', 'type': 'function'}   648341471
# 546    546          {'name': 'MPI_Bcast', 'type': 'function'}   735825621
# 547    547          {'name': 'MPI_Bcast', 'type': 'function'}   773033178
# 548    548          {'name': 'MPI_Bcast', 'type': 'function'}   904023410
# 549    549          {'name': 'MPI_Bcast', 'type': 'function'}   910828563
# 550    550          {'name': 'MPI_Bcast', 'type': 'function'}   916545844
# 551    551          {'name': 'MPI_Bcast', 'type': 'function'}  1047669656
# 552    552          {'name': 'MPI_Bcast', 'type': 'function'}  1092669097
# 553    553          {'name': 'MPI_Bcast', 'type': 'function'}  1199745191
# 554    554          {'name': 'MPI_Bcast', 'type': 'function'}  1241002328
# 555    555          {'name': 'MPI_Bcast', 'type': 'function'}  1338525356
# 556    556          {'name': 'MPI_Bcast', 'type': 'function'}  1643985974
# 557    557          {'name': 'MPI_Bcast', 'type': 'function'}  1751399784
# 558    558          {'name': 'MPI_Bcast', 'type': 'function'}  1831614453
# 559    559          {'name': 'MPI_Bcast', 'type': 'function'}  1872650737
# 560    560          {'name': 'MPI_Bcast', 'type': 'function'}  1900560005
# 561    561          {'name': 'MPI_Bcast', 'type': 'function'}  1990342466
# 562    562          {'name': 'MPI_Bcast', 'type': 'function'}  1994820022
# 563    563          {'name': 'MPI_Bcast', 'type': 'function'}  2005416547
# 564    564          {'name': 'MPI_Bcast', 'type': 'function'}  2043840030
# 565    565          {'name': 'MPI_Bcast', 'type': 'function'}  2153564759
# 566    566          {'name': 'MPI_Bcast', 'type': 'function'}  2160121726
# 567    567          {'name': 'MPI_Bcast', 'type': 'function'}  2207633519
# 568    568          {'name': 'MPI_Bcast', 'type': 'function'}  2662583836
# 569    569          {'name': 'MPI_Bcast', 'type': 'function'}  2801232280
# 570    570          {'name': 'MPI_Bcast', 'type': 'function'}  3000126522
# 571    571          {'name': 'MPI_Bcast', 'type': 'function'}  3018927165
# 572    572          {'name': 'MPI_Bcast', 'type': 'function'}  3678870530
# 573    573          {'name': 'MPI_Bcast', 'type': 'function'}  3790422362
# 574    574          {'name': 'MPI_Bcast', 'type': 'function'}  4124079511
# 575    575          {'name': 'MPI_Bcast', 'type': 'function'}  4289387337
# 576    576               {'name': 'comp', 'type': 'function'}    71036787
# 577    577               {'name': 'comp', 'type': 'function'}   295533304
# 578    578               {'name': 'comp', 'type': 'function'}   430275413
# 579    579               {'name': 'comp', 'type': 'function'}   566693142
# 580    580               {'name': 'comp', 'type': 'function'}   613114193
# 581    581               {'name': 'comp', 'type': 'function'}   648341471
# 582    582               {'name': 'comp', 'type': 'function'}   735825621
# 583    583               {'name': 'comp', 'type': 'function'}   773033178
# 584    584               {'name': 'comp', 'type': 'function'}   904023410
# 585    585               {'name': 'comp', 'type': 'function'}   910828563
# 586    586               {'name': 'comp', 'type': 'function'}   916545844
# 587    587               {'name': 'comp', 'type': 'function'}  1047669656
# 588    588               {'name': 'comp', 'type': 'function'}  1092669097
# 589    589               {'name': 'comp', 'type': 'function'}  1199745191
# 590    590               {'name': 'comp', 'type': 'function'}  1241002328
# 591    591               {'name': 'comp', 'type': 'function'}  1338525356
# 592    592               {'name': 'comp', 'type': 'function'}  1643985974
# 593    593               {'name': 'comp', 'type': 'function'}  1751399784
# 594    594               {'name': 'comp', 'type': 'function'}  1831614453
# 595    595               {'name': 'comp', 'type': 'function'}  1872650737
# 596    596               {'name': 'comp', 'type': 'function'}  1900560005
# 597    597               {'name': 'comp', 'type': 'function'}  1990342466
# 598    598               {'name': 'comp', 'type': 'function'}  1994820022
# 599    599               {'name': 'comp', 'type': 'function'}  2005416547
# 600    600               {'name': 'comp', 'type': 'function'}  2043840030
# 601    601               {'name': 'comp', 'type': 'function'}  2153564759
# 602    602               {'name': 'comp', 'type': 'function'}  2160121726
# 603    603               {'name': 'comp', 'type': 'function'}  2207633519
# 604    604               {'name': 'comp', 'type': 'function'}  2662583836
# 605    605               {'name': 'comp', 'type': 'function'}  2801232280
# 606    606               {'name': 'comp', 'type': 'function'}  3000126522
# 607    607               {'name': 'comp', 'type': 'function'}  3018927165
# 608    608               {'name': 'comp', 'type': 'function'}  3678870530
# 609    609               {'name': 'comp', 'type': 'function'}  3790422362
# 610    610               {'name': 'comp', 'type': 'function'}  4124079511
# 611    611               {'name': 'comp', 'type': 'function'}  4289387337
# 612    612         {'name': 'comp_large', 'type': 'function'}    71036787
# 613    613         {'name': 'comp_large', 'type': 'function'}   295533304
# 614    614         {'name': 'comp_large', 'type': 'function'}   430275413
# 615    615         {'name': 'comp_large', 'type': 'function'}   566693142
# 616    616         {'name': 'comp_large', 'type': 'function'}   613114193
# 617    617         {'name': 'comp_large', 'type': 'function'}   648341471
# 618    618         {'name': 'comp_large', 'type': 'function'}   735825621
# 619    619         {'name': 'comp_large', 'type': 'function'}   773033178
# 620    620         {'name': 'comp_large', 'type': 'function'}   904023410
# 621    621         {'name': 'comp_large', 'type': 'function'}   910828563
# ...
# 564          MPI_Bcast          8     reverse   268435456    sample
# 565          MPI_Bcast        128  1perturbed   268435456    sample
# 566          MPI_Bcast         32  1perturbed   268435456    sample
# 567          MPI_Bcast         64     reverse   268435456    sample
# 568          MPI_Bcast         16  1perturbed   268435456    sample
# 569          MPI_Bcast         32      random   268435456    sample
# 570          MPI_Bcast        512      random   268435456    sample
# 571          MPI_Bcast          2      sorted   268435456    sample
# 572          MPI_Bcast        512      sorted   268435456    sample
# 573          MPI_Bcast        256      sorted   268435456    sample
# 574          MPI_Bcast          2  1perturbed   268435456    sample
# 575          MPI_Bcast        256  1perturbed   268435456    sample
# 576               comp         16      sorted   268435456    sample
# 577               comp          8      sorted   268435456    sample
# 578               comp          4  1perturbed   268435456    sample
# 579               comp          8  1perturbed   268435456    sample
# 580               comp         16     reverse   268435456    sample
# 581               comp          2     reverse   268435456    sample
# 582               comp          4     reverse   268435456    sample
# 583               comp        128      random   268435456    sample
# 584               comp        128     reverse   268435456    sample
# 585               comp         32      sorted   268435456    sample
# 586               comp        128      sorted   268435456    sample
# 587               comp         64      random   268435456    sample
# 588               comp        256     reverse   268435456    sample
# 589               comp          4      random   268435456    sample
# 590               comp        512     reverse   268435456    sample
# 591               comp          2      random   268435456    sample
# 592               comp        512  1perturbed   268435456    sample
# 593               comp          4      sorted   268435456    sample
# 594               comp         32     reverse   268435456    sample
# 595               comp        256      random   268435456    sample
# 596               comp         16      random   268435456    sample
# 597               comp          8      random   268435456    sample
# 598               comp         64      sorted   268435456    sample
# 599               comp         64  1perturbed   268435456    sample
# 600               comp          8     reverse   268435456    sample
# 601               comp        128  1perturbed   268435456    sample
# 602               comp         32  1perturbed   268435456    sample
# 603               comp         64     reverse   268435456    sample
# 604               comp         16  1perturbed   268435456    sample
# 605               comp         32      random   268435456    sample
# 606               comp        512      random   268435456    sample
# 607               comp          2      sorted   268435456    sample
# 608               comp        512      sorted   268435456    sample
# 609               comp        256      sorted   268435456    sample
# 610               comp          2  1perturbed   268435456    sample
# 611               comp        256  1perturbed   268435456    sample
# 612         comp_large         16      sorted   268435456    sample
# 613         comp_large          8      sorted   268435456    sample
# 614         comp_large          4  1perturbed   268435456    sample
# 615         comp_large          8  1perturbed   268435456    sample
# 616         comp_large         16     reverse   268435456    sample
# 617         comp_large          2     reverse   268435456    sample
# 618         comp_large          4     reverse   268435456    sample
# 619         comp_large        128      random   268435456    sample
# 620         comp_large        128     reverse   268435456    sample
# 621         comp_large         32      sorted   268435456    sample
# 622         comp_large        128      sorted   268435456    sample
# 623         comp_large         64      random   268435456    sample
# 624         comp_large        256     reverse   268435456    sample
# 625         comp_large          4      random   268435456    sample
# 626         comp_large        512     reverse   268435456    sample
# 627         comp_large          2      random   268435456    sample
# 628         comp_large        512  1perturbed   268435456    sample
# 629         comp_large          4      sorted   268435456    sample
# 630         comp_large         32     reverse   268435456    sample
# 631         comp_large        256      random   268435456    sample
# 632         comp_large         16      random   268435456    sample
# 633         comp_large          8      random   268435456    sample
# 634         comp_large         64      sorted   268435456    sample
# 635         comp_large         64  1perturbed   268435456    sample
# 636         comp_large          8     reverse   268435456    sample
# 637         comp_large        128  1perturbed   268435456    sample
# 638         comp_large         32  1perturbed   268435456    sample
# 639         comp_large         64     reverse   268435456    sample
# 640         comp_large         16  1perturbed   268435456    sample
# 641         comp_large         32      random   268435456    sample
# 642         comp_large        512      random   268435456    sample
# 643         comp_large          2      sorted   268435456    sample
# 644         comp_large        512      sorted   268435456    sample
# 645         comp_large        256      sorted   268435456    sample
# 646         comp_large          2  1perturbed   268435456    sample
# 647         comp_large        256  1perturbed   268435456    sample
# 648         comp_small         16      sorted   268435456    sample
# 649         comp_small          8      sorted   268435456    sample
# 650         comp_small          4  1perturbed   268435456    sample
# 651         comp_small          8  1perturbed   268435456    sample
# 652         comp_small         16     reverse   268435456    sample
# 653         comp_small          2     reverse   268435456    sample
# 654         comp_small          4     reverse   268435456    sample
# 655         comp_small        128      random   268435456    sample
# 656         comp_small        128     reverse   268435456    sample
# 657         comp_small         32      sorted   268435456    sample
# 658         comp_small        128      sorted   268435456    sample
# 659         comp_small         64      random   268435456    sample
# 660         comp_small        256     reverse   268435456    sample
# 661         comp_small          4      random   268435456    sample
# 662         comp_small        512     reverse   268435456    sample
# 663         comp_small          2      random   268435456    sample
# 664         comp_small        512  1perturbed   268435456    sample
# 665         comp_small          4      sorted   268435456    sample
# 666         comp_small         32     reverse   268435456    sample
# 667         comp_small        256      random   268435456    sample
# 668         comp_small         16      random   268435456    sample
# 669         comp_small          8      random   268435456    sample
# 670         comp_small         64      sorted   268435456    sample
# 671         comp_small         64  1perturbed   268435456    sample
# 672         comp_small          8     reverse   268435456    sample
# 673         comp_small        128  1perturbed   268435456    sample
# 674         comp_small         32  1perturbed   268435456    sample
# 675         comp_small         64     reverse   268435456    sample
# 676         comp_small         16  1perturbed   268435456    sample
# 677         comp_small         32      random   268435456    sample
# 678         comp_small        512      random   268435456    sample
# 679         comp_small          2      sorted   268435456    sample
# 680         comp_small        512      sorted   268435456    sample
# 681         comp_small        256      sorted   268435456    sample
# 682         comp_small          2  1perturbed   268435456    sample
# 683         comp_small        256  1perturbed   268435456    sample
# 684  correctness_check         16      sorted   268435456    sample
# 685  correctness_check          8      sorted   268435456    sample
# 686  correctness_check          4  1perturbed   268435456    sample
# 687  correctness_check          8  1perturbed   268435456    sample
# 688  correctness_check         16     reverse   268435456    sample
# 689  correctness_check          2     reverse   268435456    sample
# 690  correctness_check          4     reverse   268435456    sample
# 691  correctness_check        128      random   268435456    sample
# 692  correctness_check        128     reverse   268435456    sample
# 693  correctness_check         32      sorted   268435456    sample
# 694  correctness_check        128      sorted   268435456    sample
# 695  correctness_check         64      random   268435456    sample
# 696  correctness_check        256     reverse   268435456    sample
# 697  correctness_check          4      random   268435456    sample
# 698  correctness_check        512     reverse   268435456    sample
# 699  correctness_check          2      random   268435456    sample
# 700  correctness_check        512  1perturbed   268435456    sample
# 701  correctness_check          4      sorted   268435456    sample
# 702  correctness_check         32     reverse   268435456    sample
# 703  correctness_check        256      random   268435456    sample
# 704  correctness_check         16      random   268435456    sample
# 705  correctness_check          8      random   268435456    sample
# 706  correctness_check         64      sorted   268435456    sample
# 707  correctness_check         64  1perturbed   268435456    sample
# 708  correctness_check          8     reverse   268435456    sample
# 709  correctness_check        128  1perturbed   268435456    sample
# 710  correctness_check         32  1perturbed   268435456    sample
# 711  correctness_check         64     reverse   268435456    sample
# 712  correctness_check         16  1perturbed   268435456    sample
# 713  correctness_check         32      random   268435456    sample
# 714  correctness_check        512      random   268435456    sample
# 715  correctness_check          2      sorted   268435456    sample
# 716  correctness_check        512      sorted   268435456    sample
# 717  correctness_check        256      sorted   268435456    sample
# 718  correctness_check          2  1perturbed   268435456    sample
# 719  correctness_check        256  1perturbed   268435456    sample
# 720  data_init_runtime         16      sorted   268435456    sample
# 721  data_init_runtime          8      sorted   268435456    sample
# 722  data_init_runtime          4  1perturbed   268435456    sample
# 723  data_init_runtime          8  1perturbed   268435456    sample
# 724  data_init_runtime         16     reverse   268435456    sample
# 725  data_init_runtime          2     reverse   268435456    sample
# 726  data_init_runtime          4     reverse   268435456    sample
# 727  data_init_runtime        128      random   268435456    sample
# 728  data_init_runtime        128     reverse   268435456    sample
# 729  data_init_runtime         32      sorted   268435456    sample
# 730  data_init_runtime        128      sorted   268435456    sample
# 731  data_init_runtime         64      random   268435456    sample
# 732  data_init_runtime        256     reverse   268435456    sample
# 733  data_init_runtime          4      random   268435456    sample
# 734  data_init_runtime        512     reverse   268435456    sample
# 735  data_init_runtime          2      random   268435456    sample
# 736  data_init_runtime        512  1perturbed   268435456    sample
# 737  data_init_runtime          4      sorted   268435456    sample
# 738  data_init_runtime         32     reverse   268435456    sample
# 739  data_init_runtime        256      random   268435456    sample
# 740  data_init_runtime         16      random   268435456    sample
# 741  data_init_runtime          8      random   268435456    sample
# 742  data_init_runtime         64      sorted   268435456    sample
# 743  data_init_runtime         64  1perturbed   268435456    sample
# 744  data_init_runtime          8     reverse   268435456    sample
# 745  data_init_runtime        128  1perturbed   268435456    sample
# 746  data_init_runtime         32  1perturbed   268435456    sample
# 747  data_init_runtime         64     reverse   268435456    sample
# 748  data_init_runtime         16  1perturbed   268435456    sample
# 749  data_init_runtime         32      random   268435456    sample
# 750  data_init_runtime        512      random   268435456    sample
# 751  data_init_runtime          2      sorted   268435456    sample
# 752  data_init_runtime        512      sorted   268435456    sample
# 753  data_init_runtime        256      sorted   268435456    sample
# 754  data_init_runtime          2  1perturbed   268435456    sample
# 755  data_init_runtime        256  1perturbed   268435456    sample
# 756         MPI_Gather         16      sorted   268435456    sample
# 757         MPI_Gather          8      sorted   268435456    sample
# 758         MPI_Gather          4  1perturbed   268435456    sample
# 759         MPI_Gather          8  1perturbed   268435456    sample
# 760         MPI_Gather         16     reverse   268435456    sample
# 761         MPI_Gather          2     reverse   268435456    sample
# 762         MPI_Gather          4     reverse   268435456    sample
# 763         MPI_Gather        128      random   268435456    sample
# 764         MPI_Gather        128     reverse   268435456    sample
# 765         MPI_Gather         32      sorted   268435456    sample
# 766         MPI_Gather        128      sorted   268435456    sample
# 767         MPI_Gather         64      random   268435456    sample
# 768         MPI_Gather        256     reverse   268435456    sample
# 769         MPI_Gather          4      random   268435456    sample
# 770         MPI_Gather        512     reverse   268435456    sample
# 771         MPI_Gather          2      random   268435456    sample
# 772         MPI_Gather        512  1perturbed   268435456    sample
# 773         MPI_Gather          4      sorted   268435456    sample
# 774         MPI_Gather         32     reverse   268435456    sample
# 775         MPI_Gather        256      random   268435456    sample
# 776         MPI_Gather         16      random   268435456    sample
# 777         MPI_Gather          8      random   268435456    sample
# 778         MPI_Gather         64      sorted   268435456    sample
# 779         MPI_Gather         64  1perturbed   268435456    sample
# 780         MPI_Gather          8     reverse   268435456    sample
# 781         MPI_Gather        128  1perturbed   268435456    sample
# 782         MPI_Gather         32  1perturbed   268435456    sample
# 783         MPI_Gather         64     reverse   268435456    sample
# 784         MPI_Gather         16  1perturbed   268435456    sample
# 785         MPI_Gather         32      random   268435456    sample
# 786         MPI_Gather        512      random   268435456    sample
# 787         MPI_Gather          2      sorted   268435456    sample
# 788         MPI_Gather        512      sorted   268435456    sample
# 789         MPI_Gather        256      sorted   268435456    sample
# 790         MPI_Gather          2  1perturbed   268435456    sample
# 791         MPI_Gather        256  1perturbed   268435456    sample
